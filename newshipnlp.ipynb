# %%
from pyhanlp import *

# Keywords for ships and locations
ship_keywords = ["号", "轮", "船", "艘","舰", "军舰", "号船", "号轮", "船只", "舰艇", "船舶", "货轮", "客轮", "油轮", "潜艇", "驳船",
                 "渡船", "航母", "货船", "运输船", "航空母舰", "战舰", "核潜艇"]

location_keywords = ["港湾", "港口", "海域", "海滩", "海湾", "海岸线", "海峡", "海底", "岸边", "河口", "岛屿", "航线", "码头",
                     "航道", "海港", "水域", "水道", "河流", "湾区", "泊位", "湖泊", "湖区", "江口", "湖边", "沿海", "沿岸", "海路",
                     "领海","半岛"]

# Country mapping dictionary
country_mapping = {
    "中国": "中国", "美": "美国", "美国": "美国", "日本": "日本",  "韩国": "韩国", "韩": "韩国",
    "英国": "英国", "英": "英国", "加拿大": "加拿大", "德国": "德国", "法国": "法国", "印度": "印度", "巴西": "巴西",
    "墨西哥": "墨西哥", "俄罗斯": "俄罗斯", "俄": "俄罗斯", "意大利": "意大利", "西班牙": "西班牙", "荷兰": "荷兰",
    "瑞典": "瑞典", "挪威": "挪威", "丹麦": "丹麦", "芬兰": "芬兰", "爱尔兰": "爱尔兰", "奥地利": "奥地利", "瑞士": "瑞士",
    "新加坡": "新加坡", "马来西亚": "马来西亚", "印度尼西亚": "印度尼西亚", "泰国": "泰国", "越南": "越南", "菲律宾": "菲律宾",
    "南非": "南非", "埃及": "埃及", "肯尼亚": "肯尼亚"
}

# %%
import os

folder_name = input("Enter your foldername: ")

folder_path = "/Users/hutusheng/Desktop/database/"  + folder_name

report_texts = []

# Iterate over all files in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)

    # Check if the path is a file
    if os.path.isfile(file_path):
        with open(file_path, "r") as file:
            report_text = file.read()
            report_text = report_text.replace("账号","")
            report_texts.append(report_text)

# %%
import re
from pyhanlp import HanLP

def extract_named_entities(text):
    segment = HanLP.newSegment().enableNameRecognize(True)
    term_list = segment.seg(text)
    named_entities = []
    for term in term_list:
        if term.nature.toString() == "nr"or "nt":
            named_entities.append(term.word)
    return named_entities

def extract_name(named_entities, ship_keywords, country_mapping):
    # List of predefined ship names
    predefined_ship_names = [
        "核潜艇", "罗纳德·里根","里根","斯坦塞姆", "尼米兹", "卡尔·文森", "罗斯福", "亚伯拉罕·林肯", "乔治·华盛顿", "斯坦尼斯", "蓝岭", "安提坦", "米利厄斯",
        "夏伊洛", "柯蒂斯·威尔伯", "费兹杰罗", "史塔森", "拉森", "麦坎贝尔", "马斯廷", "丹佛", "托图加", "日耳曼城", "复仇者",
        "防卫者", "战士", "爱国者", "守卫号", "米利诺基特", "福尔河", "布伦斯维克", "胜利", "能力", "效率", "忠诚", "无暇",
        "鲍迪奇", "汉森", "USNS MARYSEARS", "USNS Howard", "USNS GUAM", "蒙哥马利", "嘉贝丽.吉弗斯", "切斯劳维尔","考彭斯"
    ]

    # Check if any of the predefined ship names are in the named_entities list
    for ship_name in predefined_ship_names:
        if ship_name in named_entities:
            return ship_name

    # Continue with the original implementation
    for i in range(len(named_entities)):
        entity = named_entities[i]
        for keyword in ship_keywords:
            if keyword in entity:
                if i > 0:
                    previous_entity = named_entities[i - 1]
                    ship_name = previous_entity
                else:
                    ship_name = entity

                valid_ship_name = all(keyword not in ship_name for keyword in ship_keywords) and \
                                  all(ship_name not in country_mapping_keyword for country_mapping_keyword in country_mapping)

                if valid_ship_name:
                    return ship_name

    return ""



def extract_location(named_entities, location_keywords):
    entity_freq = {}  # Dictionary to store the frequency of each entity

    for i in range(len(named_entities)):
        entity = named_entities[i]
        for keyword in location_keywords:
            if keyword in entity:
                if i > 0 and keyword == entity:
                    previous_entity = named_entities[i - 1]
                    location_entity = previous_entity + entity
                else:
                    location_entity = entity

                # Count the frequency of the location entity
                if location_entity in entity_freq:
                    entity_freq[location_entity] += 1
                else:
                    entity_freq[location_entity] = 1

    if entity_freq:
        # Find the entity with the highest frequency
        max_freq_entity = max(entity_freq, key=entity_freq.get)
        return max_freq_entity

    return ""


def extract_nationality(named_entities, ship_name,country_mapping):
    closest_entity = None
    min_distance = float('inf')

    for entity in named_entities:
        if entity and ship_name:
            for keyword in country_mapping.keys():
                if entity == keyword:
                    distance = abs(named_entities.index(ship_name) - named_entities.index(entity))
                    if distance < min_distance:
                        min_distance = distance
                        closest_entity = entity

    return closest_entity if closest_entity else ""

def extract_date(text):
    pattern = r"(\d{4})-(\d{2})-(\d{2})"
    pattern2 = r"(\d{4})年(\d{2})月(\d{2})日"
    pattern3 = r"((\d{2})月(\d{2})日)"  # Corrected the closing parenthesis here
    match = re.search(pattern, text)
    match2 = re.search(pattern2, text)
    match3 = re.search(pattern3, text)
    if match:
        year = match.group(1)
        month = match.group(2)
        day = match.group(3) if match.group(3) else None
        return f"{year}-{month.zfill(2)}-{day.zfill(2)}" if day else f"{year}-{month.zfill(2)}"
    elif match2:
        year = match2.group(1)
        month = match2.group(2)
        day = match2.group(3) if match2.group(3) else None
        return f"{year}-{month.zfill(2)}-{day.zfill(2)}" if day else f"{year}-{month.zfill(2)}"
    elif match3:
        month = match3.group(1)
        day = match3.group(2) if match3.group(3) else None
        return f"{month.zfill(1)}-{day.zfill(2)}" if day else f"{month.zfill(1)}"
    return None



import re

def extract_sentences(report_texts,ship_keywords,location_keywords,country_mapping):
    result_dict_list = []

    for m, report_text in enumerate(report_texts):
        # Extract named entities
        named_entities = extract_named_entities(report_text)
        named_entities = [entity for entity in named_entities if entity.isalpha()]
        named_entities = [entity for entity in named_entities if entity and isinstance(entity, str)]


        # Extract ship name
        date = extract_date(report_text)

        pattern = r"(\d{4})-(\d{2})-(\d{2})"
        pattern2 = r"(\d{4})年(\d{2})月(\d{2})日"
        report_text = re.sub(pattern, '', report_text)
        report_text = re.sub(pattern2, '', report_text)
        # Extract location
        location = extract_location(named_entities,location_keywords)

        # Extract nationality
        ship_name = extract_name(named_entities,ship_keywords,country_mapping)
        nationality = extract_nationality(named_entities, ship_name,country_mapping)
        
        # Extract date

        # Split report text into sentences
        sentences = re.split(r'[.,\s]+', report_text)

        ship_sentence = ""
        location_sentence = ""
        nationality_sentence = ""
        date_sentence = ""

        for sentence in sentences:
            if ship_name and ship_name in sentence and not ship_sentence:
                ship_sentence = sentence
            if location and location in sentence and not location_sentence:
                location_sentence = sentence
            if nationality and nationality in sentence and not nationality_sentence:
                nationality_sentence = sentence
            if date is not None and date in sentence and not date_sentence:
                date_sentence = sentence

            if ship_sentence and location_sentence and nationality_sentence and date_sentence:
                break

        result_dict = {
            "Ship Name": ship_name,
            "Location": location,
            "Nationality": nationality,
            "Date": date,
            "File Name": f"File number {m}",
            "Ship Sentence": ship_sentence,
            "Location Sentence": location_sentence,
            "Nationality Sentence": nationality_sentence,
            "Date Sentence": date_sentence
        }

        result_dict_list.append(result_dict)

    return result_dict_list

# %%
output = extract_sentences(report_texts, ship_keywords, location_keywords, country_mapping)
for dictionary in output:
    for key, value in dictionary.items():
        print(f"{key}: {value}")
    print()
# Out:
# Ship Name: 核潜艇
# Location: 韩国港口
# Nationality: 韩国
# Date: 2023-07-19
# File Name: File number 0
# Ship Sentence: 美军战略核潜艇42年来首次靠泊韩国，意欲何为？
# Location Sentence: 7月18日证实，美国海军一艘战略核潜艇，目前正在韩国釜山港停靠。这是美国战略核潜艇自1981年3月以来，首次在韩国港口停靠。
# Nationality Sentence: 美军战略核潜艇42年来首次靠泊韩国，意欲何为？
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-07-21
# File Name: File number 1
# Ship Sentence: 美战略核潜艇入韩
# Location Sentence: 央视新闻消息，据朝中社20日报道，朝鲜国防相强纯男当天发表声明，谴责美韩18日召开“核磋商小组”会议，并强调美国战略核潜艇停泊釜山港系美国40多年来首次在朝鲜半岛部署战略核武器，对朝鲜构成“最露骨而直接”的核威胁。
# Nationality Sentence: 美战略核潜艇入韩
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-07-20
# File Name: File number 2
# Ship Sentence: 美战略核潜艇停泊釜山，朝方警告：可能符合朝鲜使用核武器条件_凤凰网
# Location Sentence: 据朝中社报道，7月20日，朝鲜国防相强纯男发表谈话警告称，美国派遣俄亥俄级战略核潜艇停泊在釜山港作战基地，是40多年来第一次在朝鲜半岛地区部署的战略核武器，是对朝鲜的最为露骨而直接的核威胁，而美军战略资产部署的可见性增大，可能会符合朝鲜使用的核武器的法律条件。
# Nationality Sentence: 美战略核潜艇停泊釜山，朝方警告：可能符合朝鲜使用核武器条件_凤凰网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 海峡两岸
# Nationality: 韩国
# Date: 2023-07-19
# File Name: File number 3
# Ship Sentence: 美军战略核潜艇时隔42年停靠韩国-闽南网
# Location Sentence: 海峡两岸
# Nationality Sentence: 美军战略核潜艇时隔42年停靠韩国-闽南网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 韩国
# Date: 2023-05-03
# File Name: File number 4
# Ship Sentence: 韩媒：美一艘“俄亥俄”级核潜艇将访问韩国
# Location Sentence: 据报道，除了计划的SSBN访问，该协议还要求“更经常地”将美国战略资产部署到韩国，同时建立一个新的“核磋商小组”，使韩国可以就美国如何为朝鲜半岛的核突发事件做准备提出更多意见。
# Nationality Sentence: 韩媒：美一艘“俄亥俄”级核潜艇将访问韩国
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 韩国港口
# Nationality: 美
# Date: 2023-07-21
# File Name: File number 5
# Ship Sentence: 美核潜艇42年来首次停靠韩国港口
# Location Sentence: 美核潜艇42年来首次停靠韩国港口
# Nationality Sentence: 美核潜艇42年来首次停靠韩国港口
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 釜山港口
# Nationality: 韩国
# Date: 2023-07-19
# File Name: File number 6
# Ship Sentence: 尹锡悦登上美军战略核潜艇！在釜山港向拜登表达谢意
# Location Sentence: 据国际在线6月17日援引韩国国防部消息，当地时间6月16日上午，美国海军“俄亥俄”级核潜艇“密歇根”号驶入韩国釜山港口。
# Nationality Sentence: 每日经济新闻消息，据央视新闻报道，当地时间7月18日，正在韩国访问的美国国家安全委员会印太协调员库尔特·坎贝尔在记者会上表示，美国战略核潜艇（SSBN）目前正在釜山港停靠。
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 韩国港口
# Nationality: 美国
# Date: 2023-06-17
# File Name: File number 7
# Ship Sentence: 炫耀武力！美国核潜艇驶入韩国港口
# Location Sentence: 炫耀武力！美国核潜艇驶入韩国港口
# Nationality Sentence: 炫耀武力！美国核潜艇驶入韩国港口
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 韩
# Date: 2023-04-27
# File Name: File number 8
# Ship Sentence: 美国火力最强战略导弹核潜艇将访韩，系四十年来首次
# Location Sentence:
# Nationality Sentence: 美国火力最强战略导弹核潜艇将访韩，系四十年来首次
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2007-12-02
# File Name: File number 9
# Ship Sentence: com-美最强核潜艇突现韩国引发诸多猜测
# Location Sentence: 据韩国《朝鲜日报》11月26日报道，一艘美国海军最先进的“海狼”级攻击核潜艇于日前悄然驶入釜山港。由于这是该型潜艇首次在朝鲜半岛乃至西太平洋地区露面，消息披露后，引起了外界的种种猜测。
# Nationality Sentence: com-美最强核潜艇突现韩国引发诸多猜测
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 韩
# Date: 2023-04-27
# File Name: File number 10
# Ship Sentence: 美国火力最强战略导弹核潜艇将访韩，系四十年来首次
# Location Sentence:
# Nationality Sentence: 美国火力最强战略导弹核潜艇将访韩，系四十年来首次
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美国
# Date: 2023-07-10
# File Name: File number 11
# Ship Sentence: 外媒：朝鲜谴责美国将战略核潜艇派往朝鲜半岛
# Location Sentence: 外媒：朝鲜谴责美国将战略核潜艇派往朝鲜半岛
# Nationality Sentence: 外媒：朝鲜谴责美国将战略核潜艇派往朝鲜半岛
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 来半岛
# Nationality: 美国
# Date: 2023-07-19
# File Name: File number 12
# Ship Sentence: 时隔42年，美国战略核潜艇为何又来半岛？_上观新闻
# Location Sentence: 时隔42年，美国战略核潜艇为何又来半岛？_上观新闻
# Nationality Sentence: 时隔42年，美国战略核潜艇为何又来半岛？_上观新闻
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 美国海域
# Nationality: 美国
# Date: 2008-02-28
# File Name: File number 13
# Ship Sentence: 揭秘美国海军俄亥俄级弹道导弹核潜艇[组图]_cctv
# Location Sentence: 研发背景美国研制“俄亥俄”级核潜艇始于60年代。由于前苏联海军的崛起，反潜兵力的增强，直接威胁到当时在役的“海神”(Poseidon)导弹核潜艇的生存。而且，据美国分析，这种威胁到80年代将会更加严重。主要原因是“海神”导弹射程只有4600km，必须到靠近欧亚大陆海域才能攻击苏联，这显然然不如在美国海域附近进行攻击安全，为此美国海军需要发展射程更远的水下远程弹道导弹。并专门为此在1967年成立了“海军战略进攻和防御系统办公室”，负责制定战略力量的发展与研究计划。该计划的目标是为“海神”导弹增加第三级火箭，射程增至8300-9300km，装备它的核潜艇可在美国海域附近打击世界上任何战略目标，从而形成水下远程导弹系统计划(ULMS)，并于1971年9月14日获得批准。1972年初，ULMS-I型导弹命名为“三叉戟”-Ⅰ型(C4)导弹，ULMS计划随之称为“三叉戟”计划，同时开始发展一种新型的弹道导弹潜艇以供三叉戟导弹使用，“俄亥俄”级战略导弹核潜艇的建造计划因此浮出水面。
# Nationality Sentence: 揭秘美国海军俄亥俄级弹道导弹核潜艇[组图]_cctv
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 韩国
# Date: 2023-07-19
# File Name: File number 14
# Ship Sentence: 美国海军核潜艇42年来首次停靠韩国_全球速报_澎湃新闻-The
# Location Sentence: 对此，据朝中社7月17日报道，朝鲜劳动党中央委员会副部长金与正当天发表谈话，称当前朝鲜半岛形势远超2017年朝美双方针锋相对的对抗水准，已经达到了可能发生实质性武装冲突乃至核战争的地步。
# Nationality Sentence: 美国海军核潜艇42年来首次停靠韩国_全球速报_澎湃新闻-The
# Date Sentence:
#
# Ship Name: 核动力
# Location: 霍尔木兹海峡
# Nationality: 美
# Date: 2023-04-21
# File Name: File number 15
# Ship Sentence: 伊媒：美核动力潜艇遭伊朗海军警告后浮出水面驶离
# Location Sentence: TV）20日报道，伊朗海军潜艇已向靠近霍尔木兹海峡的一艘美国核动力潜艇发出严厉警告，并迫使其浮出水面后驶离该水域。
# Nationality Sentence: 伊媒：美核动力潜艇遭伊朗海军警告后浮出水面驶离
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-07-20
# File Name: File number 16
# Ship Sentence: 美战略核潜艇停靠韩国：韩总统登艇“致谢”
# Location Sentence: 另据韩联社报道，朝鲜于19日凌晨向朝鲜半岛东部海域发射2枚短程弹道导弹，对美军战略核潜艇前一天停靠韩国釜山港实施“针对性”示威。
# Nationality Sentence: 美战略核潜艇停靠韩国：韩总统登艇“致谢”
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美国
# Date: 2023-05-02
# File Name: File number 17
# Ship Sentence: 美国核潜艇再进朝鲜半岛？！尹锡悦要将韩国带向何方？
# Location Sentence: 美国核潜艇再进朝鲜半岛？！尹锡悦要将韩国带向何方？
# Nationality Sentence: 美国核潜艇再进朝鲜半岛？！尹锡悦要将韩国带向何方？
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 海峡两岸
# Nationality: 韩国
# Date: 2023-07-19
# File Name: File number 18
# Ship Sentence: 美军战略核潜艇时隔42年停靠韩国-闽南网
# Location Sentence: 海峡两岸
# Nationality Sentence: 美军战略核潜艇时隔42年停靠韩国-闽南网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 澳大利亚港口
# Nationality: 美
# Date: 2023-03-14
# File Name: File number 19
# Ship Sentence: 观察｜美向澳提供现役最先进核潜艇，澳海军实力将“飞起”？
# Location Sentence: 路透社称，该协议将分多个阶段进行，据一名美官员透露，在未来几年，至少有一艘美潜艇访问澳大利亚港口，以训练澳官兵如何操作，两名不愿透露姓名的美官员表示，美国将在2027年左右在西澳大利亚州部署一些核潜艇；第二步是到2030年代初期，澳大利亚将向美国购买3艘“弗吉尼亚”级二手核潜艇，并保有后续增购2艘的选择权；第三步是在三国合建一种新型核潜艇，并在澳建设核潜艇生产线。
# Nationality Sentence: 观察｜美向澳提供现役最先进核潜艇，澳海军实力将“飞起”？
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: None
# File Name: File number 20
# Ship Sentence: 美战略核潜艇到韩国，朝鲜国防相警告：可能符合朝鲜使用核武器条件。-24小时-虎嗅网
# Location Sentence: 据环球网综合报道，朝鲜国防相强纯男7月20日发表谈话，他警告美方称，美国派遣"俄亥俄"级战略核潜艇停泊在韩国釜山港作战基地，是40多年来第一次在朝鲜半岛地区部署战略核武器，也是对朝鲜最为露骨而直接的核威胁。强纯男表示，要提醒美方，“包括战略核潜艇在内的战略资产部署的可见性增大可能会符合我们国家核武力政策法令所阐明的核武器使用条件”。
# Nationality Sentence: 美战略核潜艇到韩国，朝鲜国防相警告：可能符合朝鲜使用核武器条件。-24小时-虎嗅网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 韩国港口
# Nationality: 韩国
# Date: 2023-07-19
# File Name: File number 21
# Ship Sentence: 美军战略核潜艇42年来首次靠泊韩国，意欲何为？
# Location Sentence: 7月18日证实，美国海军一艘战略核潜艇，目前正在韩国釜山港停靠。这是美国战略核潜艇自1981年3月以来，首次在韩国港口停靠。
# Nationality Sentence: 美军战略核潜艇42年来首次靠泊韩国，意欲何为？
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-07-19
# File Name: File number 22
# Ship Sentence: 数十年来首次，美战略核潜艇停靠韩国釜山港
# Location Sentence: 声明说，美国国防部近日宣布计划把战略核潜艇派往朝鲜半岛。在朝鲜半岛部署搭载核弹头的美军战略核潜艇，意味着1981年以来美国战略核武器将首次出现在半岛地区。
# Nationality Sentence: 数十年来首次，美战略核潜艇停靠韩国釜山港
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 韩国
# Date: 2023-07-19
# File Name: File number 23
# Ship Sentence: 尹锡悦登上美军核潜艇，自称“第一”！_澎湃号·媒体_澎湃新闻-The
# Location Sentence: 值得注意的是，韩联社提到，就在上述美国核潜艇18日抵达韩国数小时后，朝鲜于19日凌晨向朝鲜半岛东部海域发射2枚短程弹道导弹。报道认为，这是朝方对美军战略核潜艇前一天停靠韩国釜山港实施的“针对性”示威。
# Nationality Sentence: 据韩联社、《朝鲜日报》19日报道，美军战略核潜艇时隔42年首次到访韩国之际，韩国总统尹锡悦于当天在釜山港海军基地登上该核潜艇并发表讲话。对此，韩媒表示，这是向朝鲜发出强烈警告。
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-07-19
# File Name: File number 24
# Ship Sentence: 数十年来首次，美战略核潜艇停靠韩国釜山港
# Location Sentence: 声明说，美国国防部近日宣布计划把战略核潜艇派往朝鲜半岛。在朝鲜半岛部署搭载核弹头的美军战略核潜艇，意味着1981年以来美国战略核武器将首次出现在半岛地区。
# Nationality Sentence: 数十年来首次，美战略核潜艇停靠韩国釜山港
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 常驻泊位
# Nationality: 美国
# Date: 2021-10-28
# File Name: File number 25
# Ship Sentence: 美国核潜艇到底撞成了什么样？他们一声不吭……
# Location Sentence: 10月15日，在港的1艘专用的舰船检测维修船由常驻泊位移动到潜艇尾部，可能正对泵喷推进器进行水下探伤检查；20日该船已返回原泊位，分析已完成相关检查评估工作。同时，20日码头上的车辆物资较15日明显减少，只新建了一个小型遮棚，也没有大型起重、运输等工程车辆活动，显示美军对该核潜艇的检查已全部结束，下步维修工作正在计划中。
# Nationality Sentence: 美国核潜艇到底撞成了什么样？他们一声不吭……
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 韩国港口
# Nationality: 美国
# Date: 2023-07-19
# File Name: File number 26
# Ship Sentence: 美国战略核潜艇42年来首次在韩国港口停靠-新闻中心-北方网
# Location Sentence: 美国战略核潜艇42年来首次在韩国港口停靠-新闻中心-北方网
# Nationality Sentence: 美国战略核潜艇42年来首次在韩国港口停靠-新闻中心-北方网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 韩国
# Date: 2023-04-27
# File Name: File number 27
# Ship Sentence: 拜登宣布！美国将向韩国派核潜艇！专家：一旦动“核”恐将刺激局势恶化
# Location Sentence: 韩国是《不扩散核武器条约》的无核武器缔约国，而条约规定无核缔约国不能接受有核国家部署核武器，现在韩国同意美国在朝鲜半岛部署核潜艇，形同违约。
# Nationality Sentence: 拜登宣布！美国将向韩国派核潜艇！专家：一旦动“核”恐将刺激局势恶化
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-07-19
# File Name: File number 28
# Ship Sentence: 42年来首次！美战略核潜艇停靠韩国，可搭载80个核弹头_央广网
# Location Sentence: 另据长安街知事19日报道，韩联社指出，该级别的核潜艇上一次停靠韩国还是上世纪80年代初，美军“罗伯特・李”号（SSBN-601）核潜艇曾于1981年3月停靠韩国。记者注意到，美国战略核潜艇停靠韩国无疑是挑衅且危险的举动，给本就紧张的朝鲜半岛局势火上浇油。而这一举动的象征意义又远大于实际的军事价值。
# Nationality Sentence: 42年来首次！美战略核潜艇停靠韩国，可搭载80个核弹头_央广网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 号码头
# Nationality: 中国
# Date: 2009-03-21
# File Name: File number 29
# Ship Sentence: 美国海军核潜艇“黑鲈”号向公众开放(组图)_CCTV
# Location Sentence: 5月21日，在美国纽约曼哈顿86号码头，三名曾经在美国海军核导弹潜艇“黑鲈”号（Growler
# Nationality Sentence: com_中国中央电视台
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 在半岛
# Nationality: 韩
# Date: 2023-04-27
# File Name: File number 30
# Ship Sentence: 美将派战略核潜艇高调访韩，韩专家：美国单纯承诺只具有象征意义
# Location Sentence: 在26日的美韩元首会谈前，韩美两国官员宣布，两位元首当天将另行发表写入加强延伸威慑的《华盛顿宣言》。据韩国《中央日报》报道，该宣言的核心内容为新设核咨商小组、定期在半岛出动核潜艇等战略资产以及扩大美国核资产相关信息共享等。
# Nationality Sentence: 美将派战略核潜艇高调访韩，韩专家：美国单纯承诺只具有象征意义
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 和海底
# Nationality: 美国
# Date: 2023-03-03
# File Name: File number 31
# Ship Sentence: 澳美英预计本月公布核潜艇计划详情，澳洲称全力保护美国技术
# Location Sentence: 复旦大学美国研究中心教授韦宗友分析称。“美英向澳大利亚提供核动力潜艇技术，是在打防扩散体系的‘擦边球’。一旦打开这个‘潘多拉的盒子’，不仅可能引发美国的其他亚太盟友效仿，增加核扩散风险，还可能加剧亚太地区军备竞赛和阵营化趋势。”韦宗友指出，值得关注和警惕的是，美英澳三国之前曾表示，除了加强核动力潜艇技术合作之外，还将在高超音速和反高超音速武器研发、网络能力、人工智能、量子技术和海底能力等方面进一步深化合作。可以预见，未来“奥库斯”协议将不断推进更深层次的军事合作，其相关做法将给国际安全秩序带来严重冲击。
# Nationality Sentence: 澳美英预计本月公布核潜艇计划详情，澳洲称全力保护美国技术
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 美国海域
# Nationality: 美国
# Date: 2008-02-28
# File Name: File number 32
# Ship Sentence: 揭秘美国海军俄亥俄级弹道导弹核潜艇[组图]_cctv
# Location Sentence: 研发背景美国研制“俄亥俄”级核潜艇始于60年代。由于前苏联海军的崛起，反潜兵力的增强，直接威胁到当时在役的“海神”(Poseidon)导弹核潜艇的生存。而且，据美国分析，这种威胁到80年代将会更加严重。主要原因是“海神”导弹射程只有4600km，必须到靠近欧亚大陆海域才能攻击苏联，这显然然不如在美国海域附近进行攻击安全，为此美国海军需要发展射程更远的水下远程弹道导弹。并专门为此在1967年成立了“海军战略进攻和防御系统办公室”，负责制定战略力量的发展与研究计划。该计划的目标是为“海神”导弹增加第三级火箭，射程增至8300-9300km，装备它的核潜艇可在美国海域附近打击世界上任何战略目标，从而形成水下远程导弹系统计划(ULMS)，并于1971年9月14日获得批准。1972年初，ULMS-I型导弹命名为“三叉戟”-Ⅰ型(C4)导弹，ULMS计划随之称为“三叉戟”计划，同时开始发展一种新型的弹道导弹潜艇以供三叉戟导弹使用，“俄亥俄”级战略导弹核潜艇的建造计划因此浮出水面。
# Nationality Sentence: 揭秘美国海军俄亥俄级弹道导弹核潜艇[组图]_cctv
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2013-03-21
# File Name: File number 33
# Ship Sentence: 美派核潜艇参加美韩军演--时政--人民网
# Location Sentence: 据朝鲜官方媒体报道，20日金正恩指导了朝鲜的超精密无人机和高射火箭的军事训练。另一方面，继19日美军派出B-52核战略轰炸机参加美韩军演后，韩国军方官员20日确认，美军还在朝鲜半岛海域派出了一艘核动力攻击潜艇参与演习。
# Nationality Sentence: 美派核潜艇参加美韩军演--时政--人民网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-07-19
# File Name: File number 34
# Ship Sentence: 42年来首次！美战略核潜艇停靠韩国，可搭载80个核弹头_央广网
# Location Sentence: 另据长安街知事19日报道，韩联社指出，该级别的核潜艇上一次停靠韩国还是上世纪80年代初，美军“罗伯特・李”号（SSBN-601）核潜艇曾于1981年3月停靠韩国。记者注意到，美国战略核潜艇停靠韩国无疑是挑衅且危险的举动，给本就紧张的朝鲜半岛局势火上浇油。而这一举动的象征意义又远大于实际的军事价值。
# Nationality Sentence: 42年来首次！美战略核潜艇停靠韩国，可搭载80个核弹头_央广网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 美国
# Date: 2022-04-04
# File Name: File number 35
# Ship Sentence: 美国最新核潜艇入列
# Location Sentence:
# Nationality Sentence: 美国最新核潜艇入列
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-07-21
# File Name: File number 36
# Ship Sentence: 美战略核潜艇到韩国，朝鲜国防相警告：可能符合朝鲜使用核武器条件_中国网
# Location Sentence: 据朝中社报道，朝鲜国防相强纯男20日发表谈话，他警告美方称，美国派遣"俄亥俄"级战略核潜艇停泊在韩国釜山港作战基地，是40多年来第一次在朝鲜半岛地区部署战略核武器，也是对朝鲜最为露骨而直接的核威胁。强纯男表示，要提醒美方，“包括战略核潜艇在内的战略资产部署的可见性增大可能会符合我们国家核武力政策法令所阐明的核武器使用条件”。
# Nationality Sentence: 美战略核潜艇到韩国，朝鲜国防相警告：可能符合朝鲜使用核武器条件_中国网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 的海域
# Nationality: 韩国
# Date: 2011-07-14
# File Name: File number 37
# Ship Sentence: 中新视频-美国最新攻击型核潜艇突现韩国釜山
# Location Sentence: 13日是美军参谋长联席会议主席马伦访华的最后一天。据报道，今天上午马伦参观了东海舰队某潜艇部队，此次马伦访华，中国军方坦诚透明的态度，得到了媒体高度评价。美军在马伦访华的前后，一直在制造着一些巧合，比如说马伦到访的时候，美、日、澳南海军演刚刚结束，马伦访华期间，美军最新型的核动力潜艇“德克萨斯”号出现在了韩国釜山的海域，美方还向韩国媒体公开了核潜艇内部的设施。韩国媒体说，美国的此举不仅想威慑朝鲜，也与中国海军力量的增加有关。就这个话题，今天我们请到的两位特别评论员尹卓先生和杜文龙先生，我们一起来关注一下这个事。
# Nationality Sentence: 中新视频-美国最新攻击型核潜艇突现韩国釜山
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 南海海域
# Nationality: 美
# Date: 2023-06-20
# File Name: File number 38
# Ship Sentence: 在南海“撞山”的核潜艇2026年才能修好
# Location Sentence: 2021年10月7日，美国海军发布消息称，“康涅狄格”号在南海海域撞到不明物体，导致船体颠簸受损、人员受伤。当时，美方对事故发生的地点、过程、后果和可能带来的影响等语焉不详，招致外界批评。（海外网
# Nationality Sentence: 外媒：美造船厂任务严重积压
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 韩国
# Date: 2017-04-26
# File Name: File number 39
# Ship Sentence: [特别关注-北京]美“密歇根”号核潜艇驶入韩国釜山港_新闻频道_央视网(cctv
# Location Sentence:
# Nationality Sentence: [特别关注-北京]美“密歇根”号核潜艇驶入韩国釜山港_新闻频道_央视网(cctv
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 美国
# Date: 2019-05-28
# File Name: File number 40
# Ship Sentence: 美国有史以来最大核潜艇开工建造！将执行战略核打击任务_新闻频道_央视网(cctv
# Location Sentence:
# Nationality Sentence: 美国有史以来最大核潜艇开工建造！将执行战略核打击任务_新闻频道_央视网(cctv
# Date Sentence:
#
# Ship Name: 核动力
# Location:
# Nationality: 美
# Date: 2023-02-26
# File Name: File number 41
# Ship Sentence: 美军罕见披露美核动力潜艇已抵韩国进行“预定访问”
# Location Sentence:
# Nationality Sentence: 美军罕见披露美核动力潜艇已抵韩国进行“预定访问”
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 澳大利亚港口
# Nationality: 美国
# Date: 2023-03-09
# File Name: File number 42
# Ship Sentence: 外媒：澳大利亚将购买多达5艘美国“弗吉尼亚”级核潜艇
# Location Sentence: 其中一名美国官员称，“奥库斯”协议将分为多个阶段实施，在未来几年至少将有一艘美国潜艇访问澳大利亚港口，并在2030年底结束部署。到时候，采用英国设计和美国技术的一种新型潜艇将被建造出来。
# Nationality Sentence: 外媒：澳大利亚将购买多达5艘美国“弗吉尼亚”级核潜艇
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 号码头
# Nationality: 中国
# Date: 2009-03-21
# File Name: File number 43
# Ship Sentence: 美国海军核潜艇“黑鲈”号向公众开放(组图)_CCTV
# Location Sentence: 5月21日，在美国纽约曼哈顿86号码头，三名曾经在美国海军核导弹潜艇“黑鲈”号（Growler
# Nationality Sentence: com_中国中央电视台
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 韩国港口
# Nationality: 美
# Date: 2023-07-21
# File Name: File number 44
# Ship Sentence: 美核潜艇42年来首次停靠韩国港口
# Location Sentence: 美核潜艇42年来首次停靠韩国港口
# Nationality Sentence: 美核潜艇42年来首次停靠韩国港口
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美国
# Date: 2023-07-20
# File Name: File number 45
# Ship Sentence: 尹锡悦感谢拜登：“我是第一个登上美军战略核潜艇的美国盟国总统”
# Location Sentence: 另据韩联社报道，朝鲜于19日凌晨向朝鲜半岛东部海域发射2枚短程弹道导弹，对美军战略核潜艇前一天停靠韩国釜山港实施“针对性”示威。
# Nationality Sentence: 尹锡悦感谢拜登：“我是第一个登上美军战略核潜艇的美国盟国总统”
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 印度
# Date: 2021-09-28
# File Name: File number 46
# Ship Sentence: 日韩也想拥有核潜艇
# Location Sentence:
# Nationality Sentence: 美英要帮澳大利亚发展核潜艇一事正在产生连锁反应，除了印度高层隐晦向美国发出“求艇信号”外，“核潜艇”也成了日韩军政界的热词。自民党总裁候选人河野太郎和高市早苗明确表示支持日本拥有核潜艇，韩国军界高官发出“美国是时候重新考虑向韩国提供类似支持”的声音。
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 海军基地码头
# Nationality: 美
# Date: 2007-11-29
# File Name: File number 47
# Ship Sentence: com-美最强核潜艇首进韩国
# Location Sentence: 26日，世界最强的攻击性核潜艇美国海军海狼级二号舰“康涅狄克”号停靠在釜山市龙湖洞海军基地码头。该潜艇进入韩国尚属首次。海狼级潜艇重达9100吨，可以搭载50枚“战斧”巡航导弹等各种导弹和鱼雷。
# Nationality Sentence: com-美最强核潜艇首进韩国
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 韩
# Date: 2023-07-21
# File Name: File number 48
# Ship Sentence: 朝鲜严厉警告美韩“核磋商小组”会议和美战略核潜艇入韩——人民政协网
# Location Sentence: 新华社首尔7月20日电据朝中社20日报道，朝鲜国防相强纯男当天发表声明，谴责美韩18日召开“核磋商小组”会议，并强调美国战略核潜艇停泊釜山港系美国40多年来首次在朝鲜半岛部署战略核武器，对朝鲜构成“最露骨而直接”的核威胁。
# Nationality Sentence: 朝鲜严厉警告美韩“核磋商小组”会议和美战略核潜艇入韩——人民政协网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 大阵仗海峡
# Nationality: 美
# Date: 2023-04-06
# File Name: File number 49
# Ship Sentence: 罕见！美核航母核潜艇接连访韩，摆出航母大阵仗
# Location Sentence:
# Nationality Sentence: 罕见！美核航母核潜艇接连访韩，摆出航母大阵仗
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美国
# Date: 2023-05-01
# File Name: File number 50
# Ship Sentence: 视评线丨美国核潜艇再进朝鲜半岛？！尹锡悦要将韩国带向何方？_央广网
# Location Sentence: 视评线丨美国核潜艇再进朝鲜半岛？！尹锡悦要将韩国带向何方？_央广网
# Nationality Sentence: 视评线丨美国核潜艇再进朝鲜半岛？！尹锡悦要将韩国带向何方？_央广网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 中国
# Date: 2017-09-24
# File Name: File number 51
# Ship Sentence: 超越俄亥俄，美英共同开发史上最强大核潜艇_新闻频道_央视网(cctv
# Location Sentence:
# Nationality Sentence: 直播中国
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 中国
# Date: 2017-09-24
# File Name: File number 52
# Ship Sentence: 超越俄亥俄，美英共同开发史上最强大核潜艇_新闻频道_央视网(cctv
# Location Sentence:
# Nationality Sentence: 直播中国
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 镇海港
# Nationality: 韩
# Date: 2017-10-13
# File Name: File number 53
# Ship Sentence: 3艘核潜艇相继坐镇半岛--国际--人民网
# Location Sentence: 当地时间10月13日上午，美军“密歇根”号核动力潜艇装备150多枚战斧导弹，驶入韩国釜山港。此前，美国“图森”号核动力潜艇驶入韩国庆尚南道镇海港，美国“里根”号核动力航空母舰也计划在下周与韩国军舰进行联合演习。3艘核潜艇相继亮相半岛，美国海军动向引人关注。
# Nationality Sentence: 美军“密歇根号”抵韩
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 釜山港口
# Nationality: 韩国
# Date: 2023-06-16
# File Name: File number 54
# Ship Sentence: 美国“俄亥俄”级核潜艇驶入韩国釜山港口-闽南网
# Location Sentence: 美国“俄亥俄”级核潜艇驶入韩国釜山港口-闽南网
# Nationality Sentence: 美国“俄亥俄”级核潜艇驶入韩国釜山港口-闽南网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 美国
# Date: 2022-04-04
# File Name: File number 55
# Ship Sentence: 美国最新核潜艇入列
# Location Sentence:
# Nationality Sentence: 美国最新核潜艇入列
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 美国
# Date: 2022-04-04
# File Name: File number 56
# Ship Sentence: 美国最新核潜艇入列
# Location Sentence:
# Nationality Sentence: 美国最新核潜艇入列
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-06-16
# File Name: File number 57
# Ship Sentence: 美巡航导弹核潜艇时隔近6年再访韩，搭载150枚“战斧”导弹
# Location Sentence: 韩国联合参谋本部15日表示，当天下午7时30分许，朝鲜向朝鲜半岛东部海域发射了两枚弹道导弹，导弹飞行距离约780千米。
# Nationality Sentence: 美巡航导弹核潜艇时隔近6年再访韩，搭载150枚“战斧”导弹
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 在半岛
# Nationality: 美
# Date: 2023-02-27
# File Name: File number 58
# Ship Sentence: 美核潜艇进驻半岛，为韩国壮胆，朝称将视为宣战，中方已亮明底线
# Location Sentence: 对于首尔要求美军在半岛部署战略武器，平壤明确表示，将被朝方视为“宣战”。
# Nationality Sentence: 美核潜艇进驻半岛，为韩国壮胆，朝称将视为宣战，中方已亮明底线
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2017-04-26
# File Name: File number 59
# Ship Sentence: 美核潜艇抵釜山_新闻频道_央视网(cctv
# Location Sentence: 朝鲜半岛局势：战略武器继续集结
# Nationality Sentence: 美核潜艇抵釜山_新闻频道_央视网(cctv
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: Video湾区
# Nationality: 中国
# Date: 2023-07-19
# File Name: File number 60
# Ship Sentence: 韩媒：尹锡悦登上美军战略核潜艇-中新网视频
# Location Sentence:
# Nationality Sentence: 金融|科技|地产|汽车|快消|酒业|中国新观察|民生调查局|
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 韩国
# Date: 2007-12-04
# File Name: File number 61
# Ship Sentence: com-美最先进核潜艇现身韩国
# Location Sentence: 据韩国《朝鲜日报》１１月２６日报道，一艘美国海军最先进的“海狼”级攻击核潜艇于日前悄然驶入釜山港。由于这是该型潜艇首次在朝鲜半岛乃至西太平洋地区露面，消息披露后，引起了外界的种种猜测。
# Nationality Sentence: com-美最先进核潜艇现身韩国
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-02-28
# File Name: File number 62
# Ship Sentence: 美核潜艇驶入釜山基地，朝鲜发出警告！
# Location Sentence: 韩联社援引分析称，美军“罕见”公开在朝鲜半岛出动核潜艇的消息，意在向朝鲜发出“严厉警告”。
# Nationality Sentence: 美核潜艇驶入釜山基地，朝鲜发出警告！
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 韩国
# Date: 2023-07-19
# File Name: File number 63
# Ship Sentence: 美国海军核潜艇42年来首次停靠韩国_全球速报_澎湃新闻-The
# Location Sentence: 对此，据朝中社7月17日报道，朝鲜劳动党中央委员会副部长金与正当天发表谈话，称当前朝鲜半岛形势远超2017年朝美双方针锋相对的对抗水准，已经达到了可能发生实质性武装冲突乃至核战争的地步。
# Nationality Sentence: 美国海军核潜艇42年来首次停靠韩国_全球速报_澎湃新闻-The
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 美国海岸线
# Nationality: 美
# Date: 2022-01-19
# File Name: File number 64
# Ship Sentence: 美频频“秀肌肉”！战略核潜艇停靠关岛基地，三个航母群往中国周边聚拢
# Location Sentence: “核冲突威胁很大，我们需要做出新的承诺来缓和紧张。”《华盛顿邮报》17日称，五个核大国的最新承诺，1985年美苏领导人也有过。近40年后，美俄爆发核冲突的风险非常高，美中核冲突的风险也越来越高。就在上周，俄罗斯还隐晦地威胁要在美国周边部署战术核武器。据《纽约时报》报道，因谈判陷入僵局，俄官员暗示，可能会在离美国海岸线不远的位置部署核武器，届时俄方发射核弹后，可供美国做出反应的警告时间或将缩短至5分钟。
# Nationality Sentence: 美频频“秀肌肉”！战略核潜艇停靠关岛基地，三个航母群往中国周边聚拢
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 美
# Date: 2023-07-19
# File Name: File number 65
# Ship Sentence: 美战略核潜艇停靠釜山港，韩媒：42年来首次访问韩国_荔枝网新闻
# Location Sentence:
# Nationality Sentence: 美战略核潜艇停靠釜山港，韩媒：42年来首次访问韩国_荔枝网新闻
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 担心半岛
# Nationality: 韩
# Date: 2023-06-17
# File Name: File number 66
# Ship Sentence: 张思南：美国执意在韩部署战略核潜艇，只是针对朝鲜？
# Location Sentence: 直新闻：既然如此，美国为何执意要在韩国部署战略核潜艇，难道不担心半岛局势失控吗？
# Nationality Sentence: 张思南：美国执意在韩部署战略核潜艇，只是针对朝鲜？
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 韩国
# Date: 2023-04-27
# File Name: File number 67
# Ship Sentence: 美国40年来首次向韩国派遣弹道导弹核潜艇
# Location Sentence: 据美国科学家联合会称，在20世纪70年代后期的冷战期间，美国的弹道导弹核潜艇经常访问韩国港口，有时每月访问2到3次。当时，美国在韩国布置了数百枚核弹头。但在1991年，美国从朝鲜半岛撤回了所有核武器。
# Nationality Sentence: 美国40年来首次向韩国派遣弹道导弹核潜艇
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 海军基地码头
# Nationality: 韩国
# Date: 2007-11-29
# File Name: File number 68
# Ship Sentence: com-美军海狼级核潜艇首进韩国
# Location Sentence: 经韩国媒体确认，一艘造价高达30亿美元的世界最强的美国攻击性核潜艇正停靠在釜山市龙湖洞海军基地码头。过去“洛杉矶”级核潜艇为补给和维修多次在韩国军港停靠，但海狼级进入韩国尚属首次，所以其背景受到关注。
# Nationality Sentence: com-美军海狼级核潜艇首进韩国
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-07-20
# File Name: File number 69
# Ship Sentence: 美战略核潜艇停泊釜山，朝方警告：可能符合朝鲜使用核武器条件_凤凰网
# Location Sentence: 据朝中社报道，7月20日，朝鲜国防相强纯男发表谈话警告称，美国派遣俄亥俄级战略核潜艇停泊在釜山港作战基地，是40多年来第一次在朝鲜半岛地区部署的战略核武器，是对朝鲜的最为露骨而直接的核威胁，而美军战略资产部署的可见性增大，可能会符合朝鲜使用的核武器的法律条件。
# Nationality Sentence: 美战略核潜艇停泊釜山，朝方警告：可能符合朝鲜使用核武器条件_凤凰网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 美国
# Date: 2017-08-09
# File Name: File number 70
# Ship Sentence: 韩国希望美国帮助其制造核潜艇_新闻频道_央视网(cctv
# Location Sentence:
# Nationality Sentence: 韩国希望美国帮助其制造核潜艇_新闻频道_央视网(cctv
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 北侧港口
# Nationality: 中国
# Date: 2009-04-23
# File Name: File number 71
# Ship Sentence: 韩媒：中国核潜艇今日揭开神秘面纱_CCTV
# Location Sentence: 韩国《朝鲜日报》4月23日文章，原题：中国核潜艇今日揭开面纱吸引全球目光据悉，中国于23日在山东省青岛市举行庆祝中国海军成立60周年的活动。这一活动吸引全球军事专家的目光，是因为中国将举行大规模海上阅兵式，并首次公开其核潜艇。为参加庆祝活动，截至21日，来自美国、韩国、日本等14个国家的21艘舰艇陆续抵达青岛北侧港口。
# Nationality Sentence: 韩媒：中国核潜艇今日揭开神秘面纱_CCTV
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 釜山港口
# Nationality: 韩国
# Date: 2023-07-19
# File Name: File number 72
# Ship Sentence: 尹锡悦登上美军战略核潜艇！在釜山港向拜登表达谢意
# Location Sentence: 据国际在线6月17日援引韩国国防部消息，当地时间6月16日上午，美国海军“俄亥俄”级核潜艇“密歇根”号驶入韩国釜山港口。
# Nationality Sentence: 每日经济新闻消息，据央视新闻报道，当地时间7月18日，正在韩国访问的美国国家安全委员会印太协调员库尔特·坎贝尔在记者会上表示，美国战略核潜艇（SSBN）目前正在釜山港停靠。
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-07-21
# File Name: File number 73
# Ship Sentence: 美战略核潜艇到韩国，朝鲜国防相警告：可能符合朝鲜使用核武器条件_中国网
# Location Sentence: 据朝中社报道，朝鲜国防相强纯男20日发表谈话，他警告美方称，美国派遣"俄亥俄"级战略核潜艇停泊在韩国釜山港作战基地，是40多年来第一次在朝鲜半岛地区部署战略核武器，也是对朝鲜最为露骨而直接的核威胁。强纯男表示，要提醒美方，“包括战略核潜艇在内的战略资产部署的可见性增大可能会符合我们国家核武力政策法令所阐明的核武器使用条件”。
# Nationality Sentence: 美战略核潜艇到韩国，朝鲜国防相警告：可能符合朝鲜使用核武器条件_中国网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 进半岛
# Nationality: 美国
# Date: 2023-04-29
# File Name: File number 74
# Ship Sentence: 时隔40年韩国引美国核潜艇进半岛，吓唬谁？
# Location Sentence: 时隔40年韩国引美国核潜艇进半岛，吓唬谁？
# Nationality Sentence: 时隔40年韩国引美国核潜艇进半岛，吓唬谁？
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 号码头
# Nationality: 中国
# Date: 2009-03-21
# File Name: File number 75
# Ship Sentence: 美国海军核潜艇“黑鲈”号向公众开放(组图)_CCTV
# Location Sentence: 5月21日，在美国纽约曼哈顿86号码头，三名曾经在美国海军核导弹潜艇“黑鲈”号（Growler
# Nationality Sentence: com_中国中央电视台
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 韩
# Date: 2023-04-28
# File Name: File number 76
# Ship Sentence: 核观察｜美将派战略导弹核潜艇访韩，朝鲜半岛核对抗加剧
# Location Sentence: 核观察｜美将派战略导弹核潜艇访韩，朝鲜半岛核对抗加剧
# Nationality Sentence: 核观察｜美将派战略导弹核潜艇访韩，朝鲜半岛核对抗加剧
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 韩国港口
# Nationality: 美
# Date: 2023-07-19
# File Name: File number 77
# Ship Sentence: 42年来首次！美战略核潜艇停靠韩国
# Location Sentence: 当地时间7月18日，正在韩国访问的美国国家安全委员会印太协调员坎贝尔表示，美国战略核潜艇目前正在釜山港停靠。这是美国战略核潜艇42年来首次在韩国港口停靠。
# Nationality Sentence: 42年来首次！美战略核潜艇停靠韩国
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 港口城市
# Nationality: 美国
# Date: 2023-02-25
# File Name: File number 78
# Ship Sentence: 一艘美国核潜艇抵达釜山，韩媒炒此举是“展示武力对朝警告”
# Location Sentence: 韩联社提到，美国太平洋舰队在社交媒体上发布消息称，排水量为6000吨的“洛杉矶”级快速攻击潜艇“斯普林菲尔德”号停靠在韩国南部港口城市釜山的海军基地，进行“预定的访问”。但消息中没有透露潜艇抵达的时间。
# Nationality Sentence: 一艘美国核潜艇抵达釜山，韩媒炒此举是“展示武力对朝警告”
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 美
# Date: 2023-07-19
# File Name: File number 79
# Ship Sentence: 美战略核潜艇停靠釜山港，韩媒：42年来首次访问韩国_荔枝网新闻
# Location Sentence:
# Nationality Sentence: 美战略核潜艇停靠釜山港，韩媒：42年来首次访问韩国_荔枝网新闻
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: None
# File Name: File number 80
# Ship Sentence: 美战略核潜艇到韩国，朝鲜国防相警告：可能符合朝鲜使用核武器条件。-24小时-虎嗅网
# Location Sentence: 据环球网综合报道，朝鲜国防相强纯男7月20日发表谈话，他警告美方称，美国派遣"俄亥俄"级战略核潜艇停泊在韩国釜山港作战基地，是40多年来第一次在朝鲜半岛地区部署战略核武器，也是对朝鲜最为露骨而直接的核威胁。强纯男表示，要提醒美方，“包括战略核潜艇在内的战略资产部署的可见性增大可能会符合我们国家核武力政策法令所阐明的核武器使用条件”。
# Nationality Sentence: 美战略核潜艇到韩国，朝鲜国防相警告：可能符合朝鲜使用核武器条件。-24小时-虎嗅网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 中国
# Date: 2023-05-22
# File Name: File number 81
# Ship Sentence: 新潜艇进度拖延，美海军将对“俄亥俄”级核潜艇进行延寿
# Location Sentence:
# Nationality Sentence: 中国青年网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 美
# Date: 2023-03-18
# File Name: File number 82
# Ship Sentence: 警惕！美媒：美批准澳大利亚购买220枚“战斧”导弹，与核潜艇“配套”_新闻频道_央视网(cctv
# Location Sentence:
# Nationality Sentence: 警惕！美媒：美批准澳大利亚购买220枚“战斧”导弹，与核潜艇“配套”_新闻频道_央视网(cctv
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-06-16
# File Name: File number 83
# Ship Sentence: 美巡航导弹核潜艇时隔近6年再访韩，搭载150枚“战斧”导弹
# Location Sentence: 韩国联合参谋本部15日表示，当天下午7时30分许，朝鲜向朝鲜半岛东部海域发射了两枚弹道导弹，导弹飞行距离约780千米。
# Nationality Sentence: 美巡航导弹核潜艇时隔近6年再访韩，搭载150枚“战斧”导弹
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: Video湾区
# Nationality: 中国
# Date: 2023-07-19
# File Name: File number 84
# Ship Sentence: 韩媒：尹锡悦登上美军战略核潜艇-中新网视频
# Location Sentence:
# Nationality Sentence: 金融|科技|地产|汽车|快消|酒业|中国新观察|民生调查局|
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 亚太水域
# Nationality: 中国
# Date: 2023-03-18
# File Name: File number 85
# Ship Sentence: 美英澳联手推动更多核潜艇进入太平洋_新闻频道_中国青年网
# Location Sentence: 尽管不确定因素众多，三国仍然千方百计地推动更多核潜艇进入太平洋。美媒在分析三国这样做的动机时提到，无论是用于打击水面和水下目标、搜集情报还是执行特种作战任务，核潜艇在澳大利亚的常态化部署都具有重大意义。对美军来说，随着其在亚太水域的活动日趋频繁，如果再发生2021年“康涅狄格”号核潜艇撞击海底山脉之类的事故，设在澳大利亚的核潜艇维护保障设施就可以提供“近水楼台”的助力。
# Nationality Sentence: 美英澳联手推动更多核潜艇进入太平洋_新闻频道_中国青年网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 美
# Date: 2023-07-19
# File Name: File number 86
# Ship Sentence: 美战略核潜艇时隔42年停靠韩国意欲何为？-新闻中心-北方网
# Location Sentence:
# Nationality Sentence: 美战略核潜艇时隔42年停靠韩国意欲何为？-新闻中心-北方网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 海峡
# Nationality: 韩国
# Date: 2023-07-21
# File Name: File number 87
# Ship Sentence: [海峡新干线]美国海军核潜艇42年来首次停靠韩国
# Location Sentence: [海峡新干线]美国海军核潜艇42年来首次停靠韩国
# Nationality Sentence: [海峡新干线]美国海军核潜艇42年来首次停靠韩国
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 韩国
# Date: 2023-07-20
# File Name: File number 88
# Ship Sentence: 7月20日译名发布：“肯塔基”号核潜艇
# Location Sentence:
# Nationality Sentence: 背景介绍：据韩联社7月19日报道，韩国总统尹锡悦当天登上靠泊在釜山港的美国海军战略核潜艇“肯塔基”号并视察了潜艇内部。“肯塔基”号核潜艇是“俄亥俄”级弹道导弹核潜艇，编号SSBN-737，是美国海军中第三艘以肯塔基州之名命名的军舰。它于1990年8月下水，1991年7月正式服役，全长约170米，全宽约13米，水上排水量约16764吨，潜航排水量约18750吨，配备Mk-48型鱼雷和24枚三叉戟Ⅱ型弹道导弹。
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 中国
# Date: 2017-09-24
# File Name: File number 89
# Ship Sentence: 超越俄亥俄，美英共同开发史上最强大核潜艇_新闻频道_央视网(cctv
# Location Sentence:
# Nationality Sentence: 直播中国
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美国
# Date: 2023-07-10
# File Name: File number 90
# Ship Sentence: 外媒：朝鲜谴责美国将战略核潜艇派往朝鲜半岛
# Location Sentence: 外媒：朝鲜谴责美国将战略核潜艇派往朝鲜半岛
# Nationality Sentence: 外媒：朝鲜谴责美国将战略核潜艇派往朝鲜半岛
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美
# Date: 2023-05-07
# File Name: File number 91
# Ship Sentence: 体现特殊关系？美日韩指挥官首次同登战略核潜艇_央广网
# Location Sentence: 美韩领导人4月26日发表《华盛顿宣言》，美方承诺将强化向朝鲜半岛部署战略武器。作为具体措施之一，美方将时隔四十多年首次在韩部署战略核潜艇。
# Nationality Sentence: 体现特殊关系？美日韩指挥官首次同登战略核潜艇_央广网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 韩国
# Date: None
# File Name: File number 92
# Ship Sentence: 美军密歇根号核潜艇抵达韩国釜山
# Location Sentence:
# Nationality Sentence: 美军密歇根号核潜艇抵达韩国釜山
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 韩
# Date: 2023-07-21
# File Name: File number 93
# Ship Sentence: 朝鲜严厉警告美韩“核磋商小组”会议和美战略核潜艇入韩
# Location Sentence: 每经AI快讯，据朝中社20日报道，朝鲜国防相强纯男当天发表声明，谴责美韩18日召开“核磋商小组”会议，并强调美国战略核潜艇停泊釜山港系美国40多年来首次在朝鲜半岛部署战略核武器，对朝鲜构成“最露骨而直接”的核威胁。
# Nationality Sentence: 朝鲜严厉警告美韩“核磋商小组”会议和美战略核潜艇入韩
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 美国
# Date: 2019-05-28
# File Name: File number 94
# Ship Sentence: 美国有史以来最大核潜艇开工建造！将执行战略核打击任务_新闻频道_央视网(cctv
# Location Sentence:
# Nationality Sentence: 美国有史以来最大核潜艇开工建造！将执行战略核打击任务_新闻频道_央视网(cctv
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 韩国
# Date: 2023-07-19
# File Name: File number 95
# Ship Sentence: 尹锡悦登上美军核潜艇，自称“第一”！_澎湃号·媒体_澎湃新闻-The
# Location Sentence: 值得注意的是，韩联社提到，就在上述美国核潜艇18日抵达韩国数小时后，朝鲜于19日凌晨向朝鲜半岛东部海域发射2枚短程弹道导弹。报道认为，这是朝方对美军战略核潜艇前一天停靠韩国釜山港实施的“针对性”示威。
# Nationality Sentence: 据韩联社、《朝鲜日报》19日报道，美军战略核潜艇时隔42年首次到访韩国之际，韩国总统尹锡悦于当天在釜山港海军基地登上该核潜艇并发表讲话。对此，韩媒表示，这是向朝鲜发出强烈警告。
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 来半岛
# Nationality: 美国
# Date: 2023-07-19
# File Name: File number 96
# Ship Sentence: 时隔42年，美国战略核潜艇为何又来半岛？_上观新闻
# Location Sentence: 时隔42年，美国战略核潜艇为何又来半岛？_上观新闻
# Nationality Sentence: 时隔42年，美国战略核潜艇为何又来半岛？_上观新闻
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 美国海域
# Nationality: 美国
# Date: 2008-02-28
# File Name: File number 97
# Ship Sentence: 揭秘美国海军俄亥俄级弹道导弹核潜艇[组图]_cctv
# Location Sentence: 研发背景美国研制“俄亥俄”级核潜艇始于60年代。由于前苏联海军的崛起，反潜兵力的增强，直接威胁到当时在役的“海神”(Poseidon)导弹核潜艇的生存。而且，据美国分析，这种威胁到80年代将会更加严重。主要原因是“海神”导弹射程只有4600km，必须到靠近欧亚大陆海域才能攻击苏联，这显然然不如在美国海域附近进行攻击安全，为此美国海军需要发展射程更远的水下远程弹道导弹。并专门为此在1967年成立了“海军战略进攻和防御系统办公室”，负责制定战略力量的发展与研究计划。该计划的目标是为“海神”导弹增加第三级火箭，射程增至8300-9300km，装备它的核潜艇可在美国海域附近打击世界上任何战略目标，从而形成水下远程导弹系统计划(ULMS)，并于1971年9月14日获得批准。1972年初，ULMS-I型导弹命名为“三叉戟”-Ⅰ型(C4)导弹，ULMS计划随之称为“三叉戟”计划，同时开始发展一种新型的弹道导弹潜艇以供三叉戟导弹使用，“俄亥俄”级战略导弹核潜艇的建造计划因此浮出水面。
# Nationality Sentence: 揭秘美国海军俄亥俄级弹道导弹核潜艇[组图]_cctv
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 美国
# Date: 2019-05-28
# File Name: File number 98
# Ship Sentence: 美国有史以来最大核潜艇开工建造！将执行战略核打击任务_新闻频道_央视网(cctv
# Location Sentence:
# Nationality Sentence: 美国有史以来最大核潜艇开工建造！将执行战略核打击任务_新闻频道_央视网(cctv
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 上海滩
# Nationality: 美
# Date: 2007-11-29
# File Name: File number 99
# Ship Sentence: com-美最强核潜艇首进韩国
# Location Sentence: 上海滩
# Nationality Sentence: com-美最强核潜艇首进韩国
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 新西兰领海
# Nationality: 美国
# Date: 2023-03-15
# File Name: File number 100
# Ship Sentence: 美英澳核潜艇合作引发多方担忧
# Location Sentence: 作为“五眼联盟”一员的新西兰也对美英澳核潜艇合作有不同看法。据《新西兰先驱报》14日报道，新西兰总理希普金斯表示，新西兰“仍然是一个引以为豪的无核国家”“我们不是围绕核潜艇安排的一部分，也不会成为该安排的一部分”。他还提醒澳大利亚，20世纪80年代生效的《南太平洋无核区条约》明确禁止任何“推进力全部或部分依赖核动力”的船只进入新西兰领海。
# Nationality Sentence: 当地时间13日，美国总统拜登在加州圣迭戈美国海军基地与澳大利亚总理阿尔巴尼斯以及英国首相苏纳克举行会面，就所谓“三边安全伙伴关系”举行会谈，并公布了为澳大利亚配备核潜艇的计划。根据会后三方公布的联合声明，美国将向澳大利亚出售3艘美国“弗吉尼亚”级核潜艇，交易大概在2030年代初完成，后续可能再追加出售2艘。三国还计划，以美国和英国的技术为基础，合作研制一种新型核潜艇。澳大利亚军方官员称，整个计划预计将在2055年完成，耗资2450亿美元。
# Date Sentence:
