# %%
from pyhanlp import *
from difflib import get_close_matches
# Keywords for ships and locations
ship_keywords = ["号", "轮", "船", "艘","舰", "军舰", "号船", "号轮", "船只", "舰艇", "船舶", "货轮", "客轮", "油轮", "潜艇", "驳船",
                 "渡船", "航母", "货船", "运输船", "航空母舰", "战舰", "核潜艇"]

location_keywords = ["港湾", "港口", "海域", "海滩", "海湾", "海岸线", "海峡", "海底", "岸边", "河口", "岛屿", "航线", "码头",
                     "航道", "海港", "水域", "水道", "河流", "湾区", "泊位", "湖泊", "湖区", "江口", "湖边", "沿海", "沿岸", "海路",
                     "领海","半岛"]

# Country mapping dictionary
country_mapping = {
    "中国": "中国", "美": "美国", "美国": "美国", "日本": "日本",  "韩国": "韩国", "韩": "韩国",
    "英国": "英国", "英": "英国", "加拿大": "加拿大", "德国": "德国", "法国": "法国", "印度": "印度", "巴西": "巴西",
    "墨西哥": "墨西哥", "俄罗斯": "俄罗斯", "俄": "俄罗斯", "意大利": "意大利", "西班牙": "西班牙", "荷兰": "荷兰",
    "瑞典": "瑞典", "挪威": "挪威", "丹麦": "丹麦", "芬兰": "芬兰", "爱尔兰": "爱尔兰", "奥地利": "奥地利", "瑞士": "瑞士",
    "新加坡": "新加坡", "马来西亚": "马来西亚", "印度尼西亚": "印度尼西亚", "泰国": "泰国", "越南": "越南", "菲律宾": "菲律宾",
    "南非": "南非", "埃及": "埃及", "肯尼亚": "肯尼亚"
}

# %%
import os

folder_name = input("Enter your foldername: ")

folder_path = "/Users/hutusheng/Desktop/database/"  + folder_name

report_texts = []

# Iterate over all files in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)

    # Check if the path is a file
    if os.path.isfile(file_path):
        with open(file_path, "r") as file:
            report_text = file.read()
            report_text = report_text.replace("账号","")
            report_texts.append(report_text)

# %%
import re
from pyhanlp import HanLP

def extract_named_entities(text):
    segment = HanLP.newSegment().enableNameRecognize(True)
    term_list = segment.seg(text)
    named_entities = []
    for term in term_list:
        if term.nature.toString() == "nr"or "nt":
            named_entities.append(term.word)
    return named_entities

def extract_name(text,named_entities, ship_keywords, country_mapping):
    # List of predefined ship names
    predefined_ship_names = [
        "核潜艇", "里根","斯坦塞姆", "尼米兹", "文森", "罗斯福", "林肯", "华盛顿", "斯坦尼斯", "蓝岭", "安提坦", "米利厄斯",
        "夏伊洛", "威尔伯", "费兹杰罗", "史塔森", "拉森", "麦坎贝尔", "马斯廷", "丹佛", "托图加", "日耳曼城", "复仇者",
        "防卫者", "战士", "爱国者", "守卫号", "米利诺基特", "福尔河", "布伦斯维克",
        "鲍迪奇", "汉森", "USNS MARYSEARS", "USNS Howard", "USNS GUAM", "蒙哥马利", "嘉贝丽.吉弗斯", "切斯劳维尔","考彭斯"
    ]

    # Check if any of the predefined ship names are in the named_entities list
    for ship_name in predefined_ship_names:
        if ship_name in text:
            return ship_name

    # Continue with the original implementation
    for i in range(len(named_entities)):
        entity = named_entities[i]
        for keyword in ship_keywords:
            if keyword in entity:
                if i > 0:
                    previous_entity = named_entities[i - 1]
                    ship_name = previous_entity
                else:
                    ship_name = entity

                valid_ship_name = all(keyword not in ship_name for keyword in ship_keywords) and \
                                  all(ship_name not in country_mapping_keyword for country_mapping_keyword in country_mapping)

                if valid_ship_name:
                    return ship_name

    return ""



def extract_location(named_entities, ship_name,location_keywords):

    predefinedlocation=['台湾海峡', '韩国海峡', '琉球海峡', '南中国海', '东中国海', '菲律宾海', '朝鲜半岛', '马来半岛', '中国东海', 
    '南海诸岛', '日本列岛', '马六甲海峡', '巽他海峡', '博斯普鲁斯海峡', '达尔封海峡', '霍尔木兹海峡', 
    '台湾海峡', '麦哲伦海峡', '喜马拉雅山脉', '克拉科夫海', '南沙群岛', '西沙群岛', '东沙群岛', '钓鱼岛', '济州岛']
    if ship_name in named_entities:
        start = named_entities.index(ship_name)
        for i in range(0, len(named_entities) - start):
            for keyword in predefinedlocation:
                if keyword == named_entities[start + i]:
                    return named_entities[start + i]
                if keyword == named_entities[start - i]:
                    return named_entities[start - i]
    
    for location in predefinedlocation:
        if location in named_entities:
            return location
    entity_freq = {}  # Dictionary to store the frequency of each entity

    for i in range(len(named_entities)):
        entity = named_entities[i]
        for keyword in location_keywords:
            if keyword in entity:
                if i > 0 and keyword == entity:
                    previous_entity = named_entities[i - 1]
                    location_entity = previous_entity + entity
                else:
                    location_entity = entity

                # Count the frequency of the location entity
                if location_entity in entity_freq:
                    entity_freq[location_entity] += 1
                else:
                    entity_freq[location_entity] = 1

    if entity_freq:
        # Find the entity with the highest frequency
        max_freq_entity = max(entity_freq, key=entity_freq.get)
        return max_freq_entity

    return ""




def extract_nationality(named_entities, ship_name, country_mapping):
    if ship_name in named_entities:
        start = named_entities.index(ship_name)
        for i in range(0, len(named_entities) - start):
            for keyword in country_mapping.keys():
                if keyword == named_entities[start + i]:
                    return named_entities[start + i]
                if keyword == named_entities[start - i]:
                    return named_entities[start - i]
    else:
        country_count = {}
        for country in country_mapping.keys():
            country_count[country] = country_count.get(country, 0) + 1
        most_frequent_country = max(country_count, key=country_count.get)
        return most_frequent_country
                    

        




def extract_date(text):
    pattern = r"(\d{4})-(\d{2})-(\d{2})"
    pattern2 = r"(\d{4})年(\d{2})月(\d{2})日"
    pattern3 = r"((\d{2})月(\d{2})日)"  # Corrected the closing parenthesis here
    match = re.search(pattern, text)
    match2 = re.search(pattern2, text)
    match3 = re.search(pattern3, text)
    if match:
        year = match.group(1)
        month = match.group(2)
        day = match.group(3) if match.group(3) else None
        return f"{year}-{month.zfill(2)}-{day.zfill(2)}" if day else f"{year}-{month.zfill(2)}"
    elif match2:
        year = match2.group(1)
        month = match2.group(2)
        day = match2.group(3) if match2.group(3) else None
        return f"{year}-{month.zfill(2)}-{day.zfill(2)}" if day else f"{year}-{month.zfill(2)}"
    elif match3:
        month = match3.group(1)
        day = match3.group(2) if match3.group(3) else None
        return f"{month.zfill(1)}-{day.zfill(2)}" if day else f"{month.zfill(1)}"
    return None



import re

def extract_sentences(report_texts,ship_keywords,location_keywords,country_mapping):
    result_dict_list = []

    for m, report_text in enumerate(report_texts):
        # Extract named entities
        named_entities = extract_named_entities(report_text)
        named_entities = [entity for entity in named_entities if entity.isalpha()]
        named_entities = [entity for entity in named_entities if entity and isinstance(entity, str)]


        # Extract ship name
        date = extract_date(report_text)

        pattern = r"(\d{4})-(\d{2})-(\d{2})"
        pattern2 = r"(\d{4})年(\d{2})月(\d{2})日"
        report_text = re.sub(pattern, '', report_text)
        report_text = re.sub(pattern2, '', report_text)
        # Extract location
    

        # Extract nationality
        ship_name = extract_name(report_text,named_entities,ship_keywords,country_mapping)
        location = extract_location(named_entities,ship_name,location_keywords)
        nationality = extract_nationality(named_entities, ship_name,country_mapping)
        
        # Extract date

        # Split report text into sentences
        sentences = re.split(r'[.,\s]+', report_text)

        ship_sentence = ""
        location_sentence = ""
        nationality_sentence = ""
        date_sentence = ""

        for sentence in sentences:
            if ship_name and ship_name in sentence and not ship_sentence:
                ship_sentence = sentence
            if location and location in sentence and not location_sentence:
                location_sentence = sentence
            if nationality and nationality in sentence and not nationality_sentence:
                nationality_sentence = sentence
            if date is not None and date in sentence and not date_sentence:
                date_sentence = sentence

            if ship_sentence and location_sentence and nationality_sentence and date_sentence:
                break

        result_dict = {
            "Ship Name": ship_name,
            "Location": location,
            "Nationality": nationality,
            "Date": date,
            "File Name": f"File number {m}",
            "Ship Sentence": ship_sentence,
            "Location Sentence": location_sentence,
            "Nationality Sentence": nationality_sentence,
            "Date Sentence": date_sentence
        }

        result_dict_list.append(result_dict)

    return result_dict_list

# %%
output = extract_sentences(report_texts, ship_keywords, location_keywords, country_mapping)
for dictionary in output:
    for key, value in dictionary.items():
        print(f"{key}: {value}")
    print()
# Out:
# Ship Name: 核潜艇
# Location: 菲律宾海
# Nationality: 美国
# Date: 2023-02-20
# File Name: File number 0
# Ship Sentence: 赔钱赚吆喝！澳大利亚执意与美英推进核潜艇项目
# Location Sentence: AIS信号显示，2月20日，尼米兹号航母打击群成员“迪云”号与“韦恩·迈耶”号驱逐舰经苏里高海峡进入菲律宾海。2月19日，打击群成员“迪卡特”号与“韦恩·迈耶”号驱逐舰在苏禄海活动，同日，一架美海军P-8A反潜巡逻机自菲律宾克拉克机场起飞，提供ISR(情报、侦察、监视)支援。据三艘驱逐舰航行轨迹推断，尼米兹号航母打击群已于2月18日自巴拉巴克海峡进入苏禄海，结束此次南海部署。
# Nationality Sentence: 菲外交部抗议中方船只在南海“挑衅”，菲媒：这很可能是在“配合”美国干涉南海事务
# Date Sentence:
#
# Ship Name: 里根
# Location: 朝鲜半岛
# Nationality: 美国
# Date: 2023-04-17
# File Name: File number 1
# Ship Sentence: 韩军：美国“里根”号航母重返朝鲜半岛东部海域
# Location Sentence: 韩军：美国“里根”号航母重返朝鲜半岛东部海域
# Nationality Sentence: 【文/观察者网王世纯】根据美国国防部下属的信息发布网站DVID在4月16日报道，4月16号，美国海军“尼米兹”号（CVN-68）及其护航舰艇又一次进入南海，进行水面、空中以及水下作战训练，以及固定翼舰载机和舰载直升机的飞行训练。这是“尼米兹”号航母打击群自去年12月部署以来第3次进入南海。
# Date Sentence:
#
# Ship Name: 里根
# Location: 西沙群岛
# Nationality: 美国
# Date: 2016-07-10
# File Name: File number 2
# Ship Sentence: 日媒称，美国太平洋舰队日前宣称，部署在日本神奈川县横须贺基地的“罗纳德·里根”号核动力航母等第七舰队舰船在南海开展了警戒活动。消息发布于6月30日。
# Location Sentence: 报道称，中国军队7月5至7月11日可能正在南海西沙群岛周边实施军事演习。国际仲裁法院将于7月12日就菲律宾针对中国提交的南海问题仲裁程序作出裁决。在此前夕美军出动航母似乎意在牵制中国，相关各国的活动也趋于活跃。
# Nationality Sentence: 日媒称，美国太平洋舰队日前宣称，部署在日本神奈川县横须贺基地的“罗纳德·里根”号核动力航母等第七舰队舰船在南海开展了警戒活动。消息发布于6月30日。
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: 美国
# Date: 2023-02-20
# File Name: File number 3
# Ship Sentence: 美国“尼米兹”航母打击群和“马金岛”两栖战备群在南海演习_中国航空新闻网
# Location Sentence:
# Nationality Sentence: 美国“尼米兹”航母打击群和“马金岛”两栖战备群在南海演习_中国航空新闻网
# Date Sentence:
#
# Ship Name: 里根
# Location: 朝鲜半岛
# Nationality: 中国
# Date: 2023-04-22
# File Name: File number 4
# Ship Sentence: 由于舰龄普遍在几十年，该型航母的故障率越来越高，其大修时间也越来越久，根据美国海军的部署，一艘尼米兹级航母的大修时间理应在半年左右，但在最近几年，尼米兹号，林肯号以及肯尼迪号等航母的大修时间普遍达到了一年甚至超过了一年之久，由于航母大修时间超出预估，其他航母的部署时间不得不延长，在去年，里根号航母的部署时间就首次超过了12个月，超期部署也让航母老化的程度越来越快。
# Location Sentence: 最近一段时间以来，东亚地区的安全形势变得越来越严峻，在台海地区，美国从去年开始就一直在试图挑战中国底线，不仅与台湾当局往来密切，同时还多次为其提供武器，违反一个中国政策，而在朝鲜半岛，美韩之间也在不断加大对朝鲜的施压力度，导致朝鲜连续试射导弹，使战争爆发的可能性大幅增加。除了这两个地区以外，南海地区近期也并不太平，而美国也同样与之有关。
# Nationality Sentence: 最近一段时间以来，东亚地区的安全形势变得越来越严峻，在台海地区，美国从去年开始就一直在试图挑战中国底线，不仅与台湾当局往来密切，同时还多次为其提供武器，违反一个中国政策，而在朝鲜半岛，美韩之间也在不断加大对朝鲜的施压力度，导致朝鲜连续试射导弹，使战争爆发的可能性大幅增加。除了这两个地区以外，南海地区近期也并不太平，而美国也同样与之有关。
# Date Sentence:
#
# Ship Name: 里根
# Location: 菲律宾海
# Nationality: 美国
# Date: 2022-07-29
# File Name: File number 5
# Ship Sentence: “里根”号航母紧急再进南海想干啥？
# Location Sentence: 综合之前媒体报道，“里根”号航空母舰5月8日离开日本佐世保港，开始2022年度战斗部署前的准备。之后“里根”号航母打击群在6月参加了在菲律宾海举行的“勇敢之盾”演习，7月中旬从菲律宾海通过巴拉巴克海峡进入南海，并先后在南海进行演练。该舰22日抵达新加坡进行访问，26日离开新加坡。
# Nationality Sentence: 美国“里根”号航母打击群又进南海！综合南海战略态势感知以及美国海军发布的信息，美国海军“里根”号航母打击群完成对新加坡的访问后，紧急进入南海。此外，一架美军RC-135V侦察机在27日异常进入南海上空。中国军事专家表示，从目前“里根”号航母开足马力北上的情况来看，它很可能是为佩洛西可能的窜访台湾做准备，而RC-135V则有可能为B-2轰炸机的巡航探路。美军如果将这些行动付诸实施，将极大增加地区不稳定因素。
# Date Sentence:
#
# Ship Name: 里根
# Location: 南中国海
# Nationality: 中国
# Date: 2017-01-08
# File Name: File number 6
# Ship Sentence: 美国航母编队轮流驻守在太平洋。从去年夏天起在南中国海和日本地区值班的是“约翰·斯坦尼斯”号航母和“罗纳德·里根”号航母率领的编队。还有两个航母打击群长期驻守地中海区域和美国东海岸。
# Location Sentence: 俄罗斯太平洋舰队副司令爱德华·米哈伊洛夫少将表示，俄罗斯还很可能与中国和马来西亚在南中国海举行联合军演，该区域的主权争议是几十年来紧张关系和潜在冲突的主要根源。
# Nationality Sentence: 直播中国
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 南海诸岛
# Nationality: 美
# Date: 2023-01-17
# File Name: File number 7
# Ship Sentence: 中美航母同处南海后，美“尼米兹”号为何高速驶离？
# Location Sentence: 当然，单就在南海海域来说，解放军有各种手段盯防美军航母编队。毕竟，这是中国家门口，且九段线内的南海诸岛是中国领土。譬如这次“尼米兹”号以及其打击群的“邦克山”号巡洋舰，“钟云”号、“迪卡特”号与“韦恩·迈耶”号驱逐舰进入南海以后，据美国有线电视新闻网（CNN）引用五角大楼官员的话说，“打击群遭到了两艘中国舰艇的跟踪”。
# Nationality Sentence: 中美航母同处南海后，美“尼米兹”号为何高速驶离？
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 东沙群岛
# Nationality: 美
# Date: 2021-10-31
# File Name: File number 8
# Ship Sentence: 军事专家杜文龙分析称，10月初，美军事故核潜艇“康涅狄格”号驶到关岛做撞击部位损伤评估后，“玛丽·西尔斯”号就来了。它有两个目标，一是“补盲区”，二是“搞示威”。
# Location Sentence: 前往东沙群岛东南海域
# Nationality Sentence: 美军舰船同时现身东海、南海，想搞什么事情？
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 南海诸岛
# Nationality: 美
# Date: 2023-01-17
# File Name: File number 9
# Ship Sentence: 中美航母同处南海后，美“尼米兹”号为何高速驶离？
# Location Sentence: 当然，单就在南海海域来说，解放军有各种手段盯防美军航母编队。毕竟，这是中国家门口，且九段线内的南海诸岛是中国领土。譬如这次“尼米兹”号以及其打击群的“邦克山”号巡洋舰，“钟云”号、“迪卡特”号与“韦恩·迈耶”号驱逐舰进入南海以后，据美国有线电视新闻网（CNN）引用五角大楼官员的话说，“打击群遭到了两艘中国舰艇的跟踪”。
# Nationality Sentence: 中美航母同处南海后，美“尼米兹”号为何高速驶离？
# Date Sentence:
#
# Ship Name: 罗斯福
# Location: 马六甲海峡
# Nationality: 美
# Date: 2021-04-04
# File Name: File number 10
# Ship Sentence: 警惕！美“罗斯福”号航母进入南海
# Location Sentence: 消息，据AIS信号显示，4月4日上午8时许，美海军“罗斯福”号航母打击群——“罗斯福”号航母、“拉塞尔”号驱逐舰、“邦克山”号巡洋舰——经由马六甲海峡进入南海活动。
# Nationality Sentence: 警惕！美“罗斯福”号航母进入南海
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 朝鲜半岛
# Nationality: 美国
# Date: 2016-05-01
# File Name: File number 11
# Ship Sentence: 美国向朝鲜半岛派核潜艇参加韩美联合反潜演习
# Location Sentence: 美国向朝鲜半岛派核潜艇参加韩美联合反潜演习
# Nationality Sentence: 美国航母战斗群访问香港被拒停靠
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 菲律宾海
# Nationality: 美国
# Date: 2023-03-28
# File Name: File number 12
# Ship Sentence: 核潜艇合作？纯属是花澳大利亚的钱为美国办事！
# Location Sentence: 3月21日至24日，尼米兹号航母打击群在菲律宾海活动，3月25日至26日，两艘驱逐舰经大隅海峡驶入东海。
# Nationality Sentence: 核潜艇合作？纯属是花澳大利亚的钱为美国办事！
# Date Sentence:
#
# Ship Name: 里根
# Location: 西沙领海
# Nationality: 中国
# Date: 2022-07-15
# File Name: File number 13
# Ship Sentence: 最近美国正在搅动南海局势，此前美国军舰擅闯西沙领海，结果遭到解放军驱离。7月13日，美国里根号航母打击群也被发现进入南海，将举行军事演习；与此同时，美国国务卿布林肯也拿所谓的南海仲裁案进行炒作，声称如果菲律宾遭受攻击，美国将履行保卫盟友的义务。
# Location Sentence: 最近美国正在搅动南海局势，此前美国军舰擅闯西沙领海，结果遭到解放军驱离。7月13日，美国里根号航母打击群也被发现进入南海，将举行军事演习；与此同时，美国国务卿布林肯也拿所谓的南海仲裁案进行炒作，声称如果菲律宾遭受攻击，美国将履行保卫盟友的义务。
# Nationality Sentence: 每年的这几天，美国以及其他西方国家的政客、媒体都要掀起一股针对中国的狂潮，因为在6年前的这个时候，发生了所谓的“南海仲裁案”。对于这个被菲律宾前总统阿基诺三世炮制出来的闹剧，中国一开始就表明了不参与、不接受、不承认的立场，但美国依然不依不饶。
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: 俄罗斯
# Date: 2022-10-03
# File Name: File number 14
# Ship Sentence: 美海军船员爆料！“尼米兹”号航母燃料泄漏污染饮用水，指挥官撒谎
# Location Sentence:
# Nationality Sentence: 【环球网报道】据“今日俄罗斯”（RT）当地时间2日报道，美国海军“尼米兹”号航母一名船员匿名举报其指挥官在燃料泄漏到船员饮用水的严重程度上撒谎，并在船员因此而生病时拒绝提供治疗。
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 台湾海峡
# Nationality: 美
# Date: 2022-01-23
# File Name: File number 15
# Ship Sentence: 我们真正要担心的，应该是水下看不见的地方。按照美军航母打击群的标准配置，一支打击群里至少会有一艘攻击型核潜艇，这次美军在南海搞出这么大动静，很难说水下有没有核潜艇给舰队开路。这玩意行动太隐蔽，很难被发现。
# Location Sentence: 而距离这里最近的热点区域，就是我们的台湾海峡以及钓鱼岛。所以，美军的意图有可能是想要在我们统一海峡两岸的时候，在南沙搞出点动静来牵制解放军，而驻扎在日本的美军也可能会提供支援。这种可能性是很值得我们去警惕的，那么我们再来看看这次登场的美军舰队战斗力如何。
# Nationality Sentence: 美国航母南海航行路线曝光，几乎绕行南沙群岛一周，或是来者不善
# Date Sentence:
#
# Ship Name: 里根
# Location: 新加坡港口
# Nationality: 美国
# Date: 2022-07-31
# File Name: File number 16
# Ship Sentence: 在过去一个多星期，中美一直就佩洛西“访台”一事进行激烈交锋，中国外交部、国防部、国台办密集发声，并展现出坚决捍卫国家主权和领土完整的坚强意志，这令美方陷入了骑虎难下的困境。日前，美国海军第七舰队证实其“里根号”航母打击群访问新加坡港口后，紧急进入南海、一架美军RC-135V侦察机异常进入南海上空，这些搅局南海的行动实施，将极大增加地区不稳定因素。
# Location Sentence: 在过去一个多星期，中美一直就佩洛西“访台”一事进行激烈交锋，中国外交部、国防部、国台办密集发声，并展现出坚决捍卫国家主权和领土完整的坚强意志，这令美方陷入了骑虎难下的困境。日前，美国海军第七舰队证实其“里根号”航母打击群访问新加坡港口后，紧急进入南海、一架美军RC-135V侦察机异常进入南海上空，这些搅局南海的行动实施，将极大增加地区不稳定因素。
# Nationality Sentence: 在过去一个多星期，中美一直就佩洛西“访台”一事进行激烈交锋，中国外交部、国防部、国台办密集发声，并展现出坚决捍卫国家主权和领土完整的坚强意志，这令美方陷入了骑虎难下的困境。日前，美国海军第七舰队证实其“里根号”航母打击群访问新加坡港口后，紧急进入南海、一架美军RC-135V侦察机异常进入南海上空，这些搅局南海的行动实施，将极大增加地区不稳定因素。
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: 美国
# Date: 2023-04-24
# File Name: File number 17
# Ship Sentence: 美军“尼米兹”号航母进入生命倒计时
# Location Sentence:
# Nationality Sentence: 在服役的第48个年头，美国海军“尼米兹”号核动力航母仍然在西太平洋上奔波，努力宣示美国在“前沿地区”的军事存在。作为美军当下最老旧的航母，“尼米兹”号的服役期已进入倒计时阶段。退役并被拆毁，是这艘10万吨重的庞然大物的归宿。
# Date Sentence:
#
# Ship Name: 里根
# Location: 马六甲海峡
# Nationality: 日本
# Date: None
# File Name: File number 18
# Ship Sentence: 石留风】美国海军研究会网站4月2日公布了美国海军水面舰艇主要舰艇兵力分布图，显示至少有3个航母战斗群、1个两栖攻击舰集群位于南海乃至亚太区域。</p><p>从该网站和美国海军官网公布的舰艇分布情况看，目前亚太海域已集结了美国海军绝大多数的大型水面舰艇部署兵力。从美国海军研究会网站发布的图表看，目前，亚太方向的第七舰队任务区内部署舰艇数量已达58艘，超过了其他舰队部署舰艇数量之和，相当于舰队部署舰艇总量(95艘)的61%。</p><p>在西太平洋海域，“里根”号航母(图标1)正在日本横须贺港进行维修保养。“黄蜂”号两栖攻击舰(图标2)搭载着美国海军陆战队第31海上远征部队投入美韩“鹞鹰”联合军演，该部队是第一支部署F-35B短距起飞/垂直降落战机的海军陆战队单位，参加演习的还有“阿什兰”号船坞登陆舰和“绿湾”两栖运输舰。</p>
# Location Sentence: <p>下一步，“黄蜂”号还将与另一艘两栖攻击舰一起参加美韩“双龙”两栖登陆演习。此外，“斯特瑞特”号驱逐舰刚刚访问香港，“杜威”号驱逐舰也进入印太海域。这两艘舰艇近年来频繁在中国周边活动，包括执行所谓的“航行自由”活动。今年它们将配合“黄蜂”号海上远征集群执行任务，并与其他两栖舰艇进行合练。</p><p>在南海海域，以“罗斯福”号(图标3)为核心的第9航母打击群于当地1日穿越马六甲海峡，短暂停靠新加坡。自去年以来，“罗斯福”号已经在美国第五舰队和美国第七舰队任务区航行半年，计划经太平洋返回美国。</p><p>在太平洋中部区域，“卡尔文森”号航母(图标4)所在的第1航母打击群已进入美国第三舰队任务区，编队内还有第2舰载航空兵中队、“张伯伦湖”号导弹巡洋舰和“韦恩·E·梅耶”号、“迈克尔·墨菲”号导弹驱逐舰。该编队计划将返回圣迭戈母港。</p><p>当然，除了该网站公布的主要水面舰艇编队外，美国军方还有大量潜艇、水面舰艇、飞行中队、“海豹”突击队、危机应对专用海军陆战队空地特遣队在包括亚太地区基地在内的地区执行任务。▲</p></section></article>1522800420000环球网版权作品，未经书面授权，严禁转载或镜像，违者将被追究法律责任。责编：liukun环球时报152280042000011["9CaKrnK7e5x"
# Nationality Sentence: 石留风】美国海军研究会网站4月2日公布了美国海军水面舰艇主要舰艇兵力分布图，显示至少有3个航母战斗群、1个两栖攻击舰集群位于南海乃至亚太区域。</p><p>从该网站和美国海军官网公布的舰艇分布情况看，目前亚太海域已集结了美国海军绝大多数的大型水面舰艇部署兵力。从美国海军研究会网站发布的图表看，目前，亚太方向的第七舰队任务区内部署舰艇数量已达58艘，超过了其他舰队部署舰艇数量之和，相当于舰队部署舰艇总量(95艘)的61%。</p><p>在西太平洋海域，“里根”号航母(图标1)正在日本横须贺港进行维修保养。“黄蜂”号两栖攻击舰(图标2)搭载着美国海军陆战队第31海上远征部队投入美韩“鹞鹰”联合军演，该部队是第一支部署F-35B短距起飞/垂直降落战机的海军陆战队单位，参加演习的还有“阿什兰”号船坞登陆舰和“绿湾”两栖运输舰。</p>
# Date Sentence:
#
# Ship Name: 里根
# Location: 台湾海峡
# Nationality: 新加坡
# Date: 2021-01-24
# File Name: File number 19
# Ship Sentence: 美军“里根”号航母再次掉头
# Location Sentence: 从政治上讲，这对中国大陆来讲是高度的挑衅。从军事上讲，这基本等同于自杀。台湾海峡实际上对美军的大型平台不是很友好。相对来说，地形比较狭窄。另外，水文条件很复杂，特别是水深情况，交通状况也非常繁忙，所以大型军舰、大型的平台从台湾海峡过的时候，都是高度紧张的，因为要防备被包括渔船等船只给撞了。
# Nationality Sentence: 据美国海军官方网站宣布，“罗斯福”号航母为旗舰的第九航母打击大队目前已经离开新加坡，并于北京时间2018年4月3日进入南海海域。而根据此前的消息，中国海军在南海举行大规模军事演习，有包括“辽宁”舰在内的40多艘舰艇参加。
# Date Sentence:
#
# Ship Name: 里根
# Location: 菲律宾海
# Nationality: 美
# Date: 2023-06-21
# File Name: File number 20
# Ship Sentence: 美“里根”号航母进入南海展开军事活动
# Location Sentence: 根据以往部署惯例，“里根”号一般在每年的5月左右开始执行“春季巡航”行动，根据地区形势，通常在日本海、菲律宾海、南海以及印度洋等海域活动。
# Nationality Sentence: 美“里根”号航母进入南海展开军事活动
# Date Sentence:
#
# Ship Name: 里根
# Location: 敌方沿岸
# Nationality: 美
# Date: 2007-08-23
# File Name: File number 21
# Ship Sentence: 此外，这还取决于国家的总体实力强弱与军费投入的多少。现代大型航母无疑是一个巨大的“吞金兽”，例如美尼米兹级“里根”号核动力航母的建造费为45亿美元，而新一代CVN78的建造费用更高达80亿美元。大型航母如此高额的费用对于一些小国来说简直就是天方夜谭。泰国2004年的全部军费预算不过19亿美元，即使全部拨给海军，还不够建造半艘尼米兹级航母。
# Location Sentence: 同时，美海军认为，在未来15年内，美海军大规模的海上作战将越来越少。美军今后面临的主要威胁是局部地区冲突对美国利益构成的损害以及针对美国本土与海外盟国的恐怖袭击等。随着美海外基地的减少，兵力前沿部署将逐步转变为兵力快速前沿投送，并迅速控制态势，对敌形成威慑。而现代海军高技术的巡航导弹、弹道导弹、舰载机、火炮等武器装备已具有对敌方沿岸及陆地纵深1500公里范围内的目标实施精确打击的能力。基于这种认识，美海军战略由“远洋作战”转变为“由海向陆作战”，即美军海上力量未来的作战行动将主要在近海区域进行，重点对陆上目标发动打击。与大型航母相比，小型航母在实现“由海向陆”作战方面将具备更多的优势。因为小型航母吃水浅，行动更加灵活方便，而且建造费用小，可装备数量更多。
# Nationality Sentence: com-美国新航母：个头更大
# Date Sentence:
#
# Ship Name: 华盛顿
# Location: 国际水域
# Nationality: 美国
# Date: 2013-12-16
# File Name: File number 22
# Ship Sentence: 《华盛顿时报》更详细地介绍了事件经过。“考彭斯”号当时正在执行针对中国航母辽宁舰的侦察任务，辽宁舰日前从中国北部的青岛港出发进入南海训练。一艘中国海军两栖登陆舰发出警告信号，要求“考彭斯”号停止前进，但“考彭斯”号拒绝听从并继续航行，因为当时所在海域属于国际水域。随后中国登陆舰驶向“考彭斯”号，并在其前方停下来，迫使“考彭斯”号转向。美方官员称这是危险的行为。法新社说，这艘中国登陆舰距美国巡洋舰不足500米。美中军舰对峙事件和平收场，但事件显示了在北京刚宣布划设东海防空识别区之后美中关系的紧张气氛。
# Location Sentence: “中美两国军舰险些在南海相撞。”美国国防部官员上周末透露的这个消息令人吃惊。美方宣称，美国导弹巡洋舰“考彭斯”号近日“在南海的国际水域合法航行”时，被一艘中国两栖登陆舰迎头逼停，“考彭斯”号紧急避让，才避免相撞。美国官员及媒体借此渲染中国舰船的做法如何“危险”、“咄咄逼人”，却对事件发生的背景轻描淡写，一笔带过——“考彭斯”号当时正抵近侦察在南海训练的中国辽宁舰航母编队。一位熟悉内情的中方消息人士15日告诉《环球时报》记者，事发当天，美方军舰已经闯入中国航母编队的“内防区”，美国现在是“恶人先告状”！“如果中国舰船跑到太平洋东海岸跟踪美国航母，美国会作何感想？”中国海军军事专家李杰以此质问美国的“强盗逻辑”。
# Nationality Sentence: 中美军舰中美军舰南海对峙逼停美国军舰辽宁舰登陆舰坦克登陆舰辽宁号航母考彭斯号昆仑山号中美关系
# Date Sentence:
#
# Ship Name: 里根
# Location: 附近海域
# Nationality: 中国
# Date: 2023-06-25
# File Name: File number 23
# Ship Sentence: 据台湾“中时新闻网”报道，日前，美军“里根号”航母打击群出现在南海附近海域，中方出动至少5艘军舰，从四个方向实现“包围”态势。此外，解放军“轰-6K”战略轰炸机贴海飞行近300公里，对美军“里根号”进行驱离。台军退役少将栗正杰表示，“轰-6K”对“里根号”航母打开火控雷达，逼使其90度大回转，显示中国大陆在南海地区已经对美军形成极大军事威慑。
# Location Sentence: 据台湾“中时新闻网”报道，日前，美军“里根号”航母打击群出现在南海附近海域，中方出动至少5艘军舰，从四个方向实现“包围”态势。此外，解放军“轰-6K”战略轰炸机贴海飞行近300公里，对美军“里根号”进行驱离。台军退役少将栗正杰表示，“轰-6K”对“里根号”航母打开火控雷达，逼使其90度大回转，显示中国大陆在南海地区已经对美军形成极大军事威慑。
# Nationality Sentence: 中国青年网
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: 韩国
# Date: 12月28日-12
# File Name: File number 24
# Ship Sentence: 尼米兹号航母的保护者
# Location Sentence:
# Nationality Sentence: jpg韩国持续暴雨近2万公顷农作物被淹
# Date Sentence:
#
# Ship Name: 切斯劳维尔
# Location: 南海海域
# Nationality: 中国
# Date: 2016-03-31
# File Name: File number 25
# Ship Sentence: （两艘军舰就这样在海上对峙着，它们相互交流着有关天气的寒暄，而各自却携带着导弹、鱼雷和重型火炮。为了检验中国是否要公开跟踪，切斯劳维尔号转了个弯，船上的军官们站在一旁观望着。之后，船上响起了来自伦肖船长另一名下级军官的喊声：“他刚转了弯，长官！”切斯劳维尔号现在有了一条尾巴。但会有多久呢？显然，中国军舰也想知道这个问题的答案。）
# Location Sentence: 据美国纽约时报3月31日报道，美国宙斯盾巡洋舰“钱斯洛斯维尔”号近日结束了在南海的活动，返回母港横须贺。“钱斯洛斯维尔”号在南海海域先后遭到了中国海军一艘护卫舰和一艘驱逐舰的拦截监视。双方舰只互相进行了喊话，纽约时报称，这是“危险的寒暄”。
# Nationality Sentence: 被中国海军舰艇监视
# Date Sentence:
#
# Ship Name: 两
# Location: 南沙群岛
# Nationality: 美国
# Date: 2019-02-11
# File Name: File number 26
# Ship Sentence: 两艘美国导弹驱逐舰今擅自闯入中国南沙岛礁12海里内
# Location Sentence: 对此，外交部新闻发言人华春莹在当天的例行记者会上表示，美国“斯普鲁恩斯”号和“普雷贝尔”号军舰，未经中国政府允许，擅自进入中国南沙群岛仁爱礁和美济礁邻近海域，中国海军依法对美舰进行了识别查证，并且予以了警告驱离。美方军舰的有关行为侵犯中国的主权，破坏有关海域的和平、安全和良好秩序。中方对此表示强烈的不满和坚决的反对。
# Nationality Sentence: 两艘美国导弹驱逐舰今擅自闯入中国南沙岛礁12海里内
# Date Sentence:
#
# Ship Name: 里根
# Location: 巴拉巴克海峡
# Nationality: 日本
# Date: 2022-01-11
# File Name: File number 27
# Ship Sentence: 除了上述两艘航母外，目前美国海军部署在亚太地区的还有停靠在日本横须贺的“里根”号航母。也就是说，在西太平洋地区，将同时出现三艘美军航母。
# Location Sentence: 据智库“南海战略态势感知平台”消息，1月9日上午，卫星在巴拉巴克海峡附近发现了美军“卡尔·文森”号航母。巴拉巴克海峡连通南海和苏禄海，是第一岛链上的战略要地。
# Nationality Sentence: 除了上述两艘航母外，目前美国海军部署在亚太地区的还有停靠在日本横须贺的“里根”号航母。也就是说，在西太平洋地区，将同时出现三艘美军航母。
# Date Sentence:
#
# Ship Name: 里根
# Location:
# Nationality: 中国
# Date: 2023-06-22
# File Name: File number 28
# Ship Sentence: 日本海上自卫队的出云号准航母已经进入南海活动，策应美军里根号航空母舰，随后还要访问越南金兰湾海军基地，而里根号航空母舰则有可能访问岘港。
# Location Sentence:
# Nationality Sentence: 中国造船能力是美国200倍
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 米海底
# Nationality: 美国
# Date: 2023-07-17
# File Name: File number 29
# Ship Sentence: 美海军航母和核潜艇通常不交于地方企业处理。除技术保密原因外，安全问题也是重要因素。位于华盛顿州的布雷默顿海军基地，是美国西海岸最大海军舰艇维修中心，负责对退役核潜艇和航母进行无害化拆解。不过，此项工作成本高昂，且周期长、工程复杂，拆解费用远超预算。比如，核燃料舱的处理，需用专门钢材“无缝包裹”后，再埋入数十米地下。一艘航母的拆解费用可能超过15亿美元，可谓是“吞金巨兽”。
# Location Sentence: 在美军主导的全球最大规模“环太平洋”海上联合军事演习中，最后环节都会举行击沉舰艇相关课目演练，其靶舰主要由退役舰艇担任。在2022年度演习中，4000吨级佩里级护卫舰“戴维斯”号就在美、英、澳、加等国火炮和鱼雷一连串攻击下，沉入4500米海底。美海军称，这使美国及其盟友获得了“最短时间实现击沉效果”的经验数据。
# Nationality Sentence: 近日，美国媒体披露了美国海军处置退役舰艇的相关情况，包括充当靶舰或试验舰，拆装封存“捐献器官”等。有分析称，美海军加大对退役舰艇处置情况宣传介绍，旨在为即将到来的舰艇“退役潮”预热。按计划，今年年底前，美海军至少有39艘各型舰艇退役。
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 号码头
# Nationality: 中国
# Date: 2014-12-23
# File Name: File number 30
# Ship Sentence: 美国紧张中国核潜艇
# Location Sentence: “福特”号航母目前正在纽波特纽斯造船厂三号码头进行后续设备安装与测试
# Nationality Sentence: 中国应建造中型或重型航母
# Date Sentence:
#
# Ship Name: 先进
# Location: 台湾海峡
# Nationality: 美国
# Date: None
# File Name: File number 31
# Ship Sentence: 近年来，美国频频派先进舰机到南海耀武扬威，非法闯入中国领海领空及岛礁邻近海空域，在涉海问题上压他国选边站队，打着维护《联合国海洋法公约》的旗号，干着维护自身海洋霸权的勾当，甚至不惜煽动地区分裂对抗。事实一再表明，在南海搞
# Location Sentence: 的正是美方。加拿大罔顾事实，不顾正义，漠视国际法，在涉海问题上竭力随美遏华，多次派军舰随美舰赴南海活动，过航台湾海峡，甘心充当美谋求霸权的帮凶。加方还倒打一耙，诬蔑中方搞胁迫，其作法令人不齿。
# Nationality Sentence: 我再次强调，所谓南海仲裁案在事实认定和法律适用上存在严重谬误，违反《联合国海洋法公约》等国际法，所作裁决是非法的、无效的。中国不接受、不参与仲裁案，不接受、不承认该裁决。南海仲裁案就是美国操弄的一场政治闹剧，目的是诬蔑打压中国，世人对此看得很清楚。
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 东海水域
# Nationality: 美国
# Date: 2023-03-27
# File Name: File number 32
# Ship Sentence: 美军“尼米兹”号航母现身东海
# Location Sentence: “南海战略态势”感知公布信息显示，美国“尼米兹”号核航母打击群，已进入东海水域
# Nationality Sentence: “南海战略态势”感知公布信息显示，美国“尼米兹”号核航母打击群，已进入东海水域
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 台湾海峡
# Nationality: 美国
# Date: 2020-04-08
# File Name: File number 33
# Ship Sentence: 美国核潜艇制造商总裁确诊
# Location Sentence: 美国军舰又过台湾海峡
# Nationality Sentence: 王世纯】美国目前部署在西海岸的“尼米兹”号航母，也出现两名新冠肺炎确诊病例。目前，该舰所有舰员已经在航母舱内进行“舰内隔离”。
# Date Sentence:
#
# Ship Name: 里根
# Location: 日本港口
# Nationality: 中国
# Date: 2021-05-26
# File Name: File number 34
# Ship Sentence: 美媒：里根号航母将从亚太地区撤出
# Location Sentence: Reagan）将从日本港口撤出并驶向阿富汗地区，预计停留4个月左右以协助美军撤离阿富汗。
# Nationality Sentence:
# Date Sentence:
#
# Ship Name: 里根
# Location: 西沙领海
# Nationality: 中国
# Date: 2022-07-15
# File Name: File number 35
# Ship Sentence: 最近美国正在搅动南海局势，此前美国军舰擅闯西沙领海，结果遭到解放军驱离。7月13日，美国里根号航母打击群也被发现进入南海，将举行军事演习；与此同时，美国国务卿布林肯也拿所谓的南海仲裁案进行炒作，声称如果菲律宾遭受攻击，美国将履行保卫盟友的义务。
# Location Sentence: 最近美国正在搅动南海局势，此前美国军舰擅闯西沙领海，结果遭到解放军驱离。7月13日，美国里根号航母打击群也被发现进入南海，将举行军事演习；与此同时，美国国务卿布林肯也拿所谓的南海仲裁案进行炒作，声称如果菲律宾遭受攻击，美国将履行保卫盟友的义务。
# Nationality Sentence: 每年的这几天，美国以及其他西方国家的政客、媒体都要掀起一股针对中国的狂潮，因为在6年前的这个时候，发生了所谓的“南海仲裁案”。对于这个被菲律宾前总统阿基诺三世炮制出来的闹剧，中国一开始就表明了不参与、不接受、不承认的立场，但美国依然不依不饶。
# Date Sentence:
#
# Ship Name: 里根
# Location: 西沙群岛
# Nationality: 美
# Date: 2022-07-15
# File Name: File number 36
# Ship Sentence: 美“里根”号航母今年首进南海，专家：意图拉拢地区国家遏制中国
# Location Sentence: 郭媛丹】美国海军13日称，“里根”号航母打击群当天进入南海执行例行任务，这是该航母编队今年首次进入南海进行军事演习。由于美国导弹驱逐舰“本福德”号刚刚非法擅闯西沙群岛，美军发布的航母最新举动引发外界关注。
# Nationality Sentence: 美“里根”号航母今年首进南海，专家：意图拉拢地区国家遏制中国
# Date Sentence:
#
# Ship Name: 里根
# Location: 朝鲜半岛
# Nationality: 韩国
# Date: 2016-10-17
# File Name: File number 37
# Ship Sentence: 美国“里根号”航空母舰结束军演
# Location Sentence: 据报道，“里根号”结束在朝鲜半岛全海域举行的韩美海上联合军演“2016不屈的意志”演习后，于16日进入釜山海军基地。
# Nationality Sentence: 当地时间10月16日，美国尼米兹级核动力航空母舰“罗纳德-里根号”（CVN-76）驶入韩国海军釜山基地。该航空母舰从10月10日至15日参加韩美”2016年度不屈意志“联合军事演习。
# Date Sentence:
#
# Ship Name: 里根
# Location: 巴海峡
# Nationality: 中国
# Date: 2023-05-05
# File Name: File number 38
# Ship Sentence: 资料图：美国海军“罗纳德·里根”号航母（来源：环球网）
# Location Sentence: 一般情况下，舰艇进入南海，要么走菲律宾岛北部的“三巴海峡”，要么走南海南部的海峡。
# Nationality Sentence:
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 菲律宾海
# Nationality: 美国
# Date: 2023-03-29
# File Name: File number 39
# Ship Sentence: 菲律宾还宣布将新增4个军事基地供美军使用，分别靠近我国台湾地区以及南海海域，这对于美国推进“印太战略”无疑有着十分重要的意义。根据最新消息，美军的3艘航母相继来到南海附近，这一行为进一步展现出美国的极端目标。美国的“美利坚”号两栖攻击舰来到菲律宾海附近，后续将会参与到精确打击演练，此外“马金岛”号两栖攻击舰也已经从日本南下进入南海海域，后续将会和另一艘两栖攻击舰进行汇合。除了这两艘两栖攻击舰之外，美国的“尼米兹”号核动力航母也已经从西太平洋地区来到台湾岛东北部。分析人士认为这是美国为了展现自己雄厚的军事力量，为此次美菲军演提供后盾。
# Location Sentence: 3艘美航母靠近中国，同时进入南海菲律宾海，山东舰与3艘055出航
# Nationality Sentence: 随着中国综合实力不断提升，美国将中国当成了重要的竞争对手，不断想要通过各种方式对中国进行挑衅和打压，巩固自己的国际霸权地位。南海问题也成了美国关注的焦点之一。一段时间以来美国致力于加强在南海周边的军事存在，和菲律宾在防务层面展开了更为密切的防务合作。根据报道显示，美菲两国此前已经签署了新的防务合作协议，将会重新在菲律宾境内部署美军部队，同时美菲两国还会举行大规模联合军演。在外界看来此次演习的主要目标便是黄岩岛，靶船也被设定在黄岩岛附近，此举是对于中国的威慑和挑衅。
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 菲律宾海
# Nationality: 美
# Date: 2023-04-20
# File Name: File number 40
# Ship Sentence: 美“尼米兹”号航母重回南海引猜测，专家：是为美菲军演“看场子”
# Location Sentence: 该新闻稿表示，这是“尼米兹”号航母打击群部署到印太地区期间第三次在南海开展行动。该航母打击群于去年12月3日从美国西海岸出发进行部署，并于12月16日进入美国第7舰队辖区。此前，它在进行港口访问后于今年4月2日离开韩国釜山港，后在东海和菲律宾海活动。4月初，“尼米兹”号航母打击群与日本海上自卫队和韩国海军在东海举行三边演习。
# Nationality Sentence: 美“尼米兹”号航母重回南海引猜测，专家：是为美菲军演“看场子”
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 南海海域
# Nationality: 美国
# Date: 2013-12-02
# File Name: File number 41
# Ship Sentence: data-alt="【中美航母或上演南海“遭遇战”】"/></i><p>人民网北京12月2日电（记者黄子娟）辽宁舰于11月29日到达三亚某军港，进行补给后将开展相关试验和训练。据媒体报道，美国“尼米兹”号和“华盛顿”号两个航母战斗群已经部署到南海海域，而日本王牌舰、排水量1
# Location Sentence: data-alt="【中美航母或上演南海“遭遇战”】"/></i><p>人民网北京12月2日电（记者黄子娟）辽宁舰于11月29日到达三亚某军港，进行补给后将开展相关试验和训练。据媒体报道，美国“尼米兹”号和“华盛顿”号两个航母战斗群已经部署到南海海域，而日本王牌舰、排水量1
# Nationality Sentence: data-alt="【中美航母或上演南海“遭遇战”】"/></i><p>人民网北京12月2日电（记者黄子娟）辽宁舰于11月29日到达三亚某军港，进行补给后将开展相关试验和训练。据媒体报道，美国“尼米兹”号和“华盛顿”号两个航母战斗群已经部署到南海海域，而日本王牌舰、排水量1
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 台湾海峡
# Nationality: 美国
# Date: 2023-06-29
# File Name: File number 42
# Ship Sentence: 王世纯】据美国海军协会网站6月28日报道，在西太平洋部署超过半年以后，当地时间6月28号，美国海军舰龄最大的航母“尼米兹”号（CVN-68）结束长达半年的部署，抵达圣迭戈海军基地，停靠K码头。此前刚刚完成换料大修，在此码头停靠的“罗斯福”号提前12个小时离开港，为尼米兹号腾出位置。
# Location Sentence: 不过，最知名的一次互动发生在第11航母打击大队的驱逐舰“钟云”号和我苏州舰的一次互动。6月上旬，美军“钟云”号导弹驱逐舰和加拿大海军“蒙特利尔”号护卫舰穿越台湾海峡时，先是“蒙特利尔”号上船员披露“苏州”号拦截美舰画面，之后美国军方官员称，中国军舰于上周六在台湾海峡以“不安全”的方式靠近了一艘美国驱逐舰，距离这艘美国军舰小于140米。
# Nationality Sentence: 美国最老航母返回港口后维护
# Date Sentence:
#
# Ship Name: 里根
# Location: 菲律宾海域
# Nationality: 菲律宾
# Date: 2018-10-19
# File Name: File number 43
# Ship Sentence: 美直升机在里根号航母甲板上坠毁
# Location Sentence: 海外网10月19日电据俄罗斯卫星通讯社报道，19日上午，美国海军一架MH-60“海鹰”直升机于起飞后不久，在里根号航空母舰的飞行甲板上坠毁，事发地位于菲律宾海域。此次坠机事件造成多名军人受伤。
# Nationality Sentence: 海外网10月19日电据俄罗斯卫星通讯社报道，19日上午，美国海军一架MH-60“海鹰”直升机于起飞后不久，在里根号航空母舰的飞行甲板上坠毁，事发地位于菲律宾海域。此次坠机事件造成多名军人受伤。
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: 美国
# Date: 2022-04-18
# File Name: File number 44
# Ship Sentence: 美军“尼米兹”号核航母即将退役
# Location Sentence:
# Nationality Sentence: 参考消息网4月18日报道据美国《国家利益》双月刊网站4月16日报道，作为“后越战时代”美国海上力量的标志，“尼米兹”号（CVN-68）核动力航母将很快从美国海军退役。
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 号码头
# Nationality: 中国
# Date: 2014-12-23
# File Name: File number 45
# Ship Sentence: 美国紧张中国核潜艇
# Location Sentence: 那么，福特级航母项目成本为何大幅增加呢？2013年9月公布的政府预算报告GAO-13-396认为，福特级航母的双频段雷达比原计划晚了4年半，拦阻装置推迟了2年半，电磁弹射系统推迟了3年，造成了8亿美元的成本上涨。同时，造船厂建造首艘航母期间遇到了诸多难题，政府方面也造成了15亿美元的成本增加。目前，首舰“福特”号正在纽波特纽斯造船厂三号码头进行为期28个月的后续设备安装，美国海军认为在未来的海试过程中还会出现许多新问题，因此还会进一步增加成本。
# Nationality Sentence: 中国应建造中型或重型航母
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: 新加坡
# Date: 2023-02-04
# File Name: File number 46
# Ship Sentence: 据新加坡亚洲新闻台2日报道，美国海军“尼米兹”号航母打击群停靠新加坡之后，已于1月26日北上重新进入南海。这是美军航母今年第2次进入南海活动。（正午国防军事）
# Location Sentence:
# Nationality Sentence: 据新加坡亚洲新闻台2日报道，美国海军“尼米兹”号航母打击群停靠新加坡之后，已于1月26日北上重新进入南海。这是美军航母今年第2次进入南海活动。（正午国防军事）
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 霍尔木兹海峡
# Nationality: 美国
# Date: 2021-01-23
# File Name: File number 47
# Ship Sentence: 伊朗一架直升机拍摄到了“佐治亚”号核潜艇。“佐治亚”号核潜艇潜望镜背后的“羽毛”在水面上清晰可见，在水面下也能看到潜艇的大致轮廓。伊朗媒体发布的视频使这艘潜艇在清澈的海水中看起来像一条人造大白鲨。
# Location Sentence: 本周早些时候，在一次展示武力的行动中，在霍尔木兹海峡附近，一艘配备了150多枚“战斧”巡航导弹的美国导弹潜艇在伊朗海军演习海域附近出现。
# Nationality Sentence: 美国《国家利益》双月刊网站1月20日发表了戴维・阿克斯的题为《什么可以取代美国航母？》的文章，文章称，目前高层的共识可能是，建造更多巨型核动力航母，或者五角大楼可能会在小型非核（常规）动力“轻型航母”上加倍下注。全文摘编如下：
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: 中国
# Date: 2015-03-04
# File Name: File number 48
# Ship Sentence: 载机比尼米兹级多
# Location Sentence:
# Nationality Sentence: 中国军网
# Date Sentence:
#
# Ship Name: 罗斯福
# Location: 海海域
# Nationality: 美国
# Date: 2021-01-27
# File Name: File number 49
# Ship Sentence: 1月23日上午10时许，美国海军“罗斯福”号航母经由巴士海峡进入南海活动，包括美海军4架P-8A反潜巡逻机、1架EP-3E电子侦察机、1架E-2C舰载预警机、1架C-2A舰载运输机在内，至少7架美军机曾在南海活动。
# Location Sentence: 需要注意的是，此次美国军舰只是在南海公海海域活动，没有进入中国主张的专属经济区或领海范围。
# Nationality Sentence: 美国航母再进南海，这次想要“拿”到什么？_澎湃号·政务_澎湃新闻-The
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 钓鱼岛
# Nationality: 中国
# Date: 2012-11-08
# File Name: File number 50
# Ship Sentence: 许多海军决策者担心，在以后的战争中航空母舰的作用可能不如核潜艇和核导弹。但是这些新理论只有在实战中才能被检验。因此，中国紧跟美国脚步并且打造与美国航母相似的艏母，是很有道理的。在过去的半个世纪中，关于“企业号”和“尼米兹”级的分析材料、图片和视频大量涌现，因此，中国首批航母很有可能是“尼米兹”级的改良版。
# Location Sentence: 不止钓鱼岛
# Nationality Sentence: 美媒：中国核动力航母或是“尼米兹”级改良版_军事频道_央视网
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: 美
# Date: 2023-07-07
# File Name: File number 51
# Ship Sentence: 美国海军尼米兹号航母。
# Location Sentence:
# Nationality Sentence: 浅说美航母生活用水污染
# Date Sentence:
#
# Ship Name: 里根
# Location: 西沙群岛
# Nationality: 美国
# Date: 2019-09-27
# File Name: File number 52
# Ship Sentence: 国防部9月26日举行9月例行记者会，国防部新闻局副局长、国防部新闻发言人任国强大校主持。会上有记者提问称，据外媒报道，国外卫星照片显示，美国“里根”号航母正在南海航行。在“里根”号航母周围出现不少疑似中国军舰的船只。请问能否证实？
# Location Sentence: 美舰擅闯我西沙群岛领海
# Nationality Sentence: 美国航母进出南海周围出现多艘中国军舰？国防部回应
# Date Sentence:
#
# Ship Name: 华盛顿
# Location: 公海水域
# Nationality: 美国
# Date: 2013-12-15
# File Name: File number 53
# Ship Sentence: 【法新社华盛顿12月13日电】美国军官今天说
# Location Sentence: 地点在南海的公海水域。最终，双方船员通过驾驶台有效沟通后，两舰再次启动，相互安全通过。”这名官员说，事发时中国最新航母辽宁舰“正在附近”。
# Nationality Sentence: 13日晚，美国媒体爆出上周中美军舰在南海对峙。正在监视辽宁号航母演习的美国“考彭斯”号导弹巡洋舰被中国海军坦克登陆舰逼停，险些相撞。美国已经通过外交和军事渠道向中国抗议。外媒分析认为，中国军舰逼停美舰或许是为了报复上个月美军B-52轰炸机闯入中国防空识别区。
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 菲律宾海
# Nationality: 日本
# Date: 2023-01-04
# File Name: File number 54
# Ship Sentence: 美海军尼米兹号航母驶向南海
# Location Sentence: 自2022年12月尼米兹号航母打击群抵达西太以来，尼米兹号航母一直在菲律宾海进行训练活动。，尼米兹号两架舰载机从关岛飞抵菲律宾克拉克机场。
# Nationality Sentence: 南海战略态势感知：卫星发现日本“加贺”号准航母在南海活动
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 红海海域
# Nationality: 美国
# Date: 2013-09-04
# File Name: File number 55
# Ship Sentence: 美国“尼米兹”号航母红海待命-中新网
# Location Sentence: 美国海军网站发布消息，当地时间9月3日，由尼米兹号核动力航母，普林斯顿号巡洋舰和三艘伯克级驱逐舰构成的尼米兹号航母战斗群进入红海海域的第五舰队任务区开始进行部署。
# Nationality Sentence: 美国“尼米兹”号航母红海待命-中新网
# Date Sentence:
#
# Ship Name: 里根
# Location:
# Nationality: 中国
# Date: 2020-04-09
# File Name: File number 56
# Ship Sentence: 综合报道，美军航母疫情频传，继“里根”号、“卡尔文森”号、“罗斯福”号航母有船员确诊感染新冠肺炎后，日前“尼米兹”号也被曝出发现感染者，使其成为第四艘出现疫情的美海军航母。
# Location Sentence:
# Nationality Sentence: _中国经济网――国家经济门户
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 菲律宾海
# Nationality: 美
# Date: 2023-04-20
# File Name: File number 57
# Ship Sentence: 美“尼米兹”号航母重回南海引猜测，专家：是为美菲军演“看场子”
# Location Sentence: 该新闻稿表示，这是“尼米兹”号航母打击群部署到印太地区期间第三次在南海开展行动。该航母打击群于去年12月3日从美国西海岸出发进行部署，并于12月16日进入美国第7舰队辖区。此前，它在进行港口访问后于今年4月2日离开韩国釜山港，后在东海和菲律宾海活动。4月初，“尼米兹”号航母打击群与日本海上自卫队和韩国海军在东海举行三边演习。
# Nationality Sentence: 美“尼米兹”号航母重回南海引猜测，专家：是为美菲军演“看场子”
# Date Sentence:
#
# Ship Name: 里根
# Location: 朝鲜半岛
# Nationality: 中国
# Date: 2017-04-15
# File Name: File number 58
# Ship Sentence: 美军“里根号”航母战斗群将抵朝鲜半岛周边
# Location Sentence: 美军“里根号”航母战斗群将抵朝鲜半岛周边
# Nationality Sentence: “法印正讨论新方案，不同于中国等国的”
# Date Sentence:
#
# Ship Name: 里根
# Location: 附近海域
# Nationality: 中国
# Date: 2006-06-19
# File Name: File number 59
# Ship Sentence: 7国观察员关岛参观美军“里根号”航母
# Location Sentence: 来自中国、澳大利亚、印度、日本、韩国、俄罗斯、新加坡等国的军官、外交官和新闻记者以观察员身份分别乘坐运输机前往关岛附近海域参观美军“里根号”、“林肯号”和“小鹰号”航母。
# Nationality Sentence: 来自中国、澳大利亚、印度、日本、韩国、俄罗斯、新加坡等国的军官、外交官和新闻记者以观察员身份分别乘坐运输机前往关岛附近海域参观美军“里根号”、“林肯号”和“小鹰号”航母。
# Date Sentence:
#
# Ship Name: 华盛顿
# Location: 国际水域
# Nationality: 美国
# Date: 2013-12-16
# File Name: File number 60
# Ship Sentence: 《华盛顿时报》更详细地介绍了事件经过。“考彭斯”号当时正在执行针对中国航母辽宁舰的侦察任务，辽宁舰日前从中国北部的青岛港出发进入南海训练。一艘中国海军两栖登陆舰发出警告信号，要求“考彭斯”号停止前进，但“考彭斯”号拒绝听从并继续航行，因为当时所在海域属于国际水域。随后中国登陆舰驶向“考彭斯”号，并在其前方停下来，迫使“考彭斯”号转向。美方官员称这是危险的行为。法新社说，这艘中国登陆舰距美国巡洋舰不足500米。美中军舰对峙事件和平收场，但事件显示了在北京刚宣布划设东海防空识别区之后美中关系的紧张气氛。
# Location Sentence: “中美两国军舰险些在南海相撞。”美国国防部官员上周末透露的这个消息令人吃惊。美方宣称，美国导弹巡洋舰“考彭斯”号近日“在南海的国际水域合法航行”时，被一艘中国两栖登陆舰迎头逼停，“考彭斯”号紧急避让，才避免相撞。美国官员及媒体借此渲染中国舰船的做法如何“危险”、“咄咄逼人”，却对事件发生的背景轻描淡写，一笔带过——“考彭斯”号当时正抵近侦察在南海训练的中国辽宁舰航母编队。一位熟悉内情的中方消息人士15日告诉《环球时报》记者，事发当天，美方军舰已经闯入中国航母编队的“内防区”，美国现在是“恶人先告状”！“如果中国舰船跑到太平洋东海岸跟踪美国航母，美国会作何感想？”中国海军军事专家李杰以此质问美国的“强盗逻辑”。
# Nationality Sentence: 中美军舰中美军舰南海对峙逼停美国军舰辽宁舰登陆舰坦克登陆舰辽宁号航母考彭斯号昆仑山号中美关系
# Date Sentence:
#
# Ship Name: 里根
# Location: 越南港口
# Nationality: 中国
# Date: 2023-06-24
# File Name: File number 61
# Ship Sentence: 美里根号航母将罕见停靠越南港口，越方称“正常友好交流”
# Location Sentence: 美里根号航母将罕见停靠越南港口，越方称“正常友好交流”
# Nationality Sentence:
# Date Sentence:
#
# Ship Name: 里根
# Location: 马六甲海峡
# Nationality: 日本
# Date: None
# File Name: File number 62
# Ship Sentence: 石留风】美国海军研究会网站4月2日公布了美国海军水面舰艇主要舰艇兵力分布图，显示至少有3个航母战斗群、1个两栖攻击舰集群位于南海乃至亚太区域。</p><p>从该网站和美国海军官网公布的舰艇分布情况看，目前亚太海域已集结了美国海军绝大多数的大型水面舰艇部署兵力。从美国海军研究会网站发布的图表看，目前，亚太方向的第七舰队任务区内部署舰艇数量已达58艘，超过了其他舰队部署舰艇数量之和，相当于舰队部署舰艇总量(95艘)的61%。</p><p>在西太平洋海域，“里根”号航母(图标1)正在日本横须贺港进行维修保养。“黄蜂”号两栖攻击舰(图标2)搭载着美国海军陆战队第31海上远征部队投入美韩“鹞鹰”联合军演，该部队是第一支部署F-35B短距起飞/垂直降落战机的海军陆战队单位，参加演习的还有“阿什兰”号船坞登陆舰和“绿湾”两栖运输舰。</p>
# Location Sentence: <p>下一步，“黄蜂”号还将与另一艘两栖攻击舰一起参加美韩“双龙”两栖登陆演习。此外，“斯特瑞特”号驱逐舰刚刚访问香港，“杜威”号驱逐舰也进入印太海域。这两艘舰艇近年来频繁在中国周边活动，包括执行所谓的“航行自由”活动。今年它们将配合“黄蜂”号海上远征集群执行任务，并与其他两栖舰艇进行合练。</p><p>在南海海域，以“罗斯福”号(图标3)为核心的第9航母打击群于当地1日穿越马六甲海峡，短暂停靠新加坡。自去年以来，“罗斯福”号已经在美国第五舰队和美国第七舰队任务区航行半年，计划经太平洋返回美国。</p><p>在太平洋中部区域，“卡尔文森”号航母(图标4)所在的第1航母打击群已进入美国第三舰队任务区，编队内还有第2舰载航空兵中队、“张伯伦湖”号导弹巡洋舰和“韦恩·E·梅耶”号、“迈克尔·墨菲”号导弹驱逐舰。该编队计划将返回圣迭戈母港。</p><p>当然，除了该网站公布的主要水面舰艇编队外，美国军方还有大量潜艇、水面舰艇、飞行中队、“海豹”突击队、危机应对专用海军陆战队空地特遣队在包括亚太地区基地在内的地区执行任务。▲</p></section></article>1522800420000环球网版权作品，未经书面授权，严禁转载或镜像，违者将被追究法律责任。责编：liukun环球时报152280042000011["9CaKrnK7e5x"
# Nationality Sentence: 石留风】美国海军研究会网站4月2日公布了美国海军水面舰艇主要舰艇兵力分布图，显示至少有3个航母战斗群、1个两栖攻击舰集群位于南海乃至亚太区域。</p><p>从该网站和美国海军官网公布的舰艇分布情况看，目前亚太海域已集结了美国海军绝大多数的大型水面舰艇部署兵力。从美国海军研究会网站发布的图表看，目前，亚太方向的第七舰队任务区内部署舰艇数量已达58艘，超过了其他舰队部署舰艇数量之和，相当于舰队部署舰艇总量(95艘)的61%。</p><p>在西太平洋海域，“里根”号航母(图标1)正在日本横须贺港进行维修保养。“黄蜂”号两栖攻击舰(图标2)搭载着美国海军陆战队第31海上远征部队投入美韩“鹞鹰”联合军演，该部队是第一支部署F-35B短距起飞/垂直降落战机的海军陆战队单位，参加演习的还有“阿什兰”号船坞登陆舰和“绿湾”两栖运输舰。</p>
# Date Sentence:
#
# Ship Name: 里根
# Location: 上港口
# Nationality: 中国
# Date: 2018-11-21
# File Name: File number 63
# Ship Sentence: 美军里根号航空母舰今天驶入中国香港进行访问。
# Location Sentence: 美海军里根号航母驶入香港时，依例挂上港口地主国的国旗。
# Nationality Sentence: 中国台湾网
# Date Sentence:
#
# Ship Name: 里根
# Location: 朝鲜半岛
# Nationality: 中国
# Date: 2023-04-22
# File Name: File number 64
# Ship Sentence: 由于舰龄普遍在几十年，该型航母的故障率越来越高，其大修时间也越来越久，根据美国海军的部署，一艘尼米兹级航母的大修时间理应在半年左右，但在最近几年，尼米兹号，林肯号以及肯尼迪号等航母的大修时间普遍达到了一年甚至超过了一年之久，由于航母大修时间超出预估，其他航母的部署时间不得不延长，在去年，里根号航母的部署时间就首次超过了12个月，超期部署也让航母老化的程度越来越快。
# Location Sentence: 最近一段时间以来，东亚地区的安全形势变得越来越严峻，在台海地区，美国从去年开始就一直在试图挑战中国底线，不仅与台湾当局往来密切，同时还多次为其提供武器，违反一个中国政策，而在朝鲜半岛，美韩之间也在不断加大对朝鲜的施压力度，导致朝鲜连续试射导弹，使战争爆发的可能性大幅增加。除了这两个地区以外，南海地区近期也并不太平，而美国也同样与之有关。
# Nationality Sentence: 最近一段时间以来，东亚地区的安全形势变得越来越严峻，在台海地区，美国从去年开始就一直在试图挑战中国底线，不仅与台湾当局往来密切，同时还多次为其提供武器，违反一个中国政策，而在朝鲜半岛，美韩之间也在不断加大对朝鲜的施压力度，导致朝鲜连续试射导弹，使战争爆发的可能性大幅增加。除了这两个地区以外，南海地区近期也并不太平，而美国也同样与之有关。
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: 美国
# Date: 2022-02-07
# File Name: File number 65
# Ship Sentence: “福特”号当然是异乎寻常的。这是尼米兹级航母的后继型号。抛开“福特”号不提，美军现役的10艘尼米兹级核动力航母，确实仍是世界上最强大的一型航母。而“福特”号旨在超越尼米兹级。
# Location Sentence:
# Nationality Sentence: 军事｜异乎寻常？美国超级航母“福特”号即将首次部署……
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 钓鱼岛
# Nationality: 美
# Date: 2014-10-28
# File Name: File number 66
# Ship Sentence: 美“尼米兹”号航母将搭载F-35C闪电II海试--军事--人民网
# Location Sentence: 日本称因未发现钓鱼岛中国飞机
# Nationality Sentence: 美“尼米兹”号航母将搭载F-35C闪电II海试--军事--人民网
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 台湾海峡
# Nationality: 美国
# Date: 2023-06-29
# File Name: File number 67
# Ship Sentence: 王世纯】据美国海军协会网站6月28日报道，在西太平洋部署超过半年以后，当地时间6月28号，美国海军舰龄最大的航母“尼米兹”号（CVN-68）结束长达半年的部署，抵达圣迭戈海军基地，停靠K码头。此前刚刚完成换料大修，在此码头停靠的“罗斯福”号提前12个小时离开港，为尼米兹号腾出位置。
# Location Sentence: 不过，最知名的一次互动发生在第11航母打击大队的驱逐舰“钟云”号和我苏州舰的一次互动。6月上旬，美军“钟云”号导弹驱逐舰和加拿大海军“蒙特利尔”号护卫舰穿越台湾海峡时，先是“蒙特利尔”号上船员披露“苏州”号拦截美舰画面，之后美国军方官员称，中国军舰于上周六在台湾海峡以“不安全”的方式靠近了一艘美国驱逐舰，距离这艘美国军舰小于140米。
# Nationality Sentence: 美国最老航母返回港口后维护
# Date Sentence:
#
# Ship Name: 哪
# Location: 西沙群岛
# Nationality: 中国
# Date: 2016-10-24
# File Name: File number 68
# Ship Sentence: 美军这次“闯南海”派了哪艘舰艇？
# Location Sentence: 美国军方向路透社透露，美国迪凯特号导弹驱逐舰（系阿利·伯克级驱逐舰）21日在南海西沙群岛海域进行了所谓“自由航行”行动，美方在通报其军舰活动范围时特别提到永兴岛(三沙市政府所在地)和中建岛，但美方表示迪凯特号没有进入相关岛屿的12海里海域。
# Nationality Sentence: 中国南海网
# Date Sentence:
#
# Ship Name: 米利厄斯
# Location: 西沙群岛
# Nationality: 中国
# Date: 2023-03-23
# File Name: File number 69
# Ship Sentence: 发言人汪文斌指出，3月23日，美国海军“米利厄斯”号军舰未经中国政府允许，进入中国西沙群岛领海，侵犯中国主权，威胁中国安全，破坏有关海域的和平与安宁。中国人民解放军南部战区依法进行跟踪监视并予以警告驱离，美方应当立即停止此类侵权挑衅行动，中方将继续采取一切必要措施，坚定捍卫国家主权和安全，维护南海和平稳定。
# Location Sentence: 美国军舰进入中国西沙群岛领海，外交部：美方应立即停止侵权挑衅
# Nationality Sentence: 美国军舰进入中国西沙群岛领海，外交部：美方应立即停止侵权挑衅
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 中国沿海
# Nationality: 美
# Date: 2023-04-12
# File Name: File number 70
# Ship Sentence: 【环球网报道】据台湾中时新闻网11日报道，民进党当局领导人蔡英文“过境”窜美后，解放军8日起启动了为期3天的环台军演。有外媒称，美军“尼米兹号”航母舰队
# Location Sentence: 对此，有岛内网友在台媒评论区留言表示，“果不失美国本色”、“美军在中国沿海只是枪靶子，只剩下放话的功能”。
# Nationality Sentence: 美航母又跑了？台名嘴讽：5000美军性命比台湾人怎么想重要
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 菲律宾海
# Nationality: 美国
# Date: 2022-01-14
# File Name: File number 71
# Ship Sentence: 另据美国媒体报道，搭载F-35C的美国海军“林肯”号航母本月3日也离开加利福尼亚州圣迭戈基地前来亚太部署，以维持在南海周边的“双航母”态势。英国广播公司报道称，“双航母”战斗群是拜登上台不到一个月就在南海推出的一项新部署。去年2月，“罗斯福”号和“尼米兹”号两个美国航母打击群同时在南海举行连串演习，目的是为了加强它们联合行动和指挥的能力。中国外交部发言人当时批评美军的活动是在“炫耀武力，不利于地区的和平与稳定”。
# Location Sentence: 值得注意的是，去年9月、10月和11月，美海军“卡尔·文森”号航母都到南海进行挑衅。甚至在11月结束与日本海上自卫队“加贺”号准航母在南海的联合行动后，就一直呆在菲律宾海附近海域，直到这次再进入南海。而同行的“埃塞克斯”号两栖戒备大队和第11海军陆战队远征单元在刚刚结束为期三个半月的在中东任务后，就直奔南海。
# Nationality Sentence: 美国又想在南海摆出“双航母”架势
# Date Sentence:
#
# Ship Name: 恩斯
# Location: 南沙群岛
# Nationality: 中国
# Date: 2019-02-18
# File Name: File number 72
# Ship Sentence: 据CCTV-7《防务新观察》报道：本月11日，美军“斯普鲁恩斯”号和“普雷贝尔”号导弹驱逐舰进入中国南沙群岛临近海域，在我军南部战区部队警告之后离开。美军的说法自然还是打着所谓“航行自由”的旗号，但是在第七舰队的官方声明中，特意说明了两艘军舰进入了南沙岛礁12海里之内。而就在今年1月7日，美国海军“麦克坎贝尔”号军舰也曾进入过中国西沙群岛领海，这也是美国第一次连续两个月在南海地区行使所谓的“航行自由”行动。
# Location Sentence: 据CCTV-7《防务新观察》报道：本月11日，美军“斯普鲁恩斯”号和“普雷贝尔”号导弹驱逐舰进入中国南沙群岛临近海域，在我军南部战区部队警告之后离开。美军的说法自然还是打着所谓“航行自由”的旗号，但是在第七舰队的官方声明中，特意说明了两艘军舰进入了南沙岛礁12海里之内。而就在今年1月7日，美国海军“麦克坎贝尔”号军舰也曾进入过中国西沙群岛领海，这也是美国第一次连续两个月在南海地区行使所谓的“航行自由”行动。
# Nationality Sentence: 直播中国
# Date Sentence:
#
# Ship Name: 里根
# Location:
# Nationality: 美国
# Date: 2019-09-27
# File Name: File number 73
# Ship Sentence: 有记者提问，据外媒报道，国外卫星照片显示，美国“里根”号航母正在南海航行。在“里根”号航母周围出现不少疑似中国军舰的船只。请问能否证实？
# Location Sentence:
# Nationality Sentence: 美国航母进南海，周围出现多艘中国军舰？解放军回应来了
# Date Sentence:
#
# Ship Name: 里根
# Location: 南海海域
# Nationality: 日本
# Date: 2022-01-20
# File Name: File number 74
# Ship Sentence: 根据卫星图像显示，美国“卡尔·文森”号进入南海地区之后将与“埃塞克斯”号共同出现在南海海域，预计在接下来的一段时间里，来自美国的航母战斗群将在南海展开联合行动。值得一提的是，停靠在日本港口的“里根”号与佐世保港提高的“美利坚”号同时处于亚太地区，如此之多的美国海军力量齐聚亚太，很显然是美国为了实现所谓“印太战略”，同时在军事上遏制中国所作出的准备。
# Location Sentence: 根据卫星图像显示，美国“卡尔·文森”号进入南海地区之后将与“埃塞克斯”号共同出现在南海海域，预计在接下来的一段时间里，来自美国的航母战斗群将在南海展开联合行动。值得一提的是，停靠在日本港口的“里根”号与佐世保港提高的“美利坚”号同时处于亚太地区，如此之多的美国海军力量齐聚亚太，很显然是美国为了实现所谓“印太战略”，同时在军事上遏制中国所作出的准备。
# Nationality Sentence: 根据卫星图像显示，美国“卡尔·文森”号进入南海地区之后将与“埃塞克斯”号共同出现在南海海域，预计在接下来的一段时间里，来自美国的航母战斗群将在南海展开联合行动。值得一提的是，停靠在日本港口的“里根”号与佐世保港提高的“美利坚”号同时处于亚太地区，如此之多的美国海军力量齐聚亚太，很显然是美国为了实现所谓“印太战略”，同时在军事上遏制中国所作出的准备。
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: None
# Date: 2023-02-15
# File Name: File number 75
# Ship Sentence: “尼米兹”号航母二进南海
# Location Sentence:
# Nationality Sentence:
# Date Sentence:
#
# Ship Name: 里根
# Location: 南部海域
# Nationality: 韩
# Date: 2016-09-12
# File Name: File number 76
# Ship Sentence: 里根号核航母下月参加韩美军演威慑朝鲜
# Location Sentence: 据韩联社9月11日报道，韩国军方11日称，“罗纳德·里根”号核动力航空母舰（CVN-76）将参加韩美两军下月10-15日在韩国西部和南部海域举行的海上联合演习。据悉，在黄海和济州以南海域进行的航母攻击群演习将集中演练在非常时刻精确打击包括朝鲜最高指挥部在内的核心设施，对不断挑衅的朝鲜释放强烈的警告信号。
# Nationality Sentence: 里根号核航母下月参加韩美军演威慑朝鲜
# Date Sentence:
#
# Ship Name: 里根
# Location:
# Nationality: 美国
# Date: 2008-02-12
# File Name: File number 77
# Ship Sentence: 据日本共同社报道，此前美国核动力航母曾8次停靠佐世保，最近一次为去年2月的“罗纳德?里根”号。本次“尼米兹”号停靠佐世保是为了舰组人员的休养和进行必要的补给。航母将停泊在港内中央部分，15日离港。
# Location Sentence:
# Nationality Sentence: 美国“尼米兹”号核航母首次停靠日本佐世保港_cctv
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 在海底
# Nationality: 美
# Date: None
# File Name: File number 78
# Ship Sentence: 对于美军在南海战机撞航母的闹剧，《解放军报》“钧正平”发表评论称，“纸老虎”吓不到人，在短短半年时间里，美军撞坏了核潜艇又坠毁了先进战机，偷鸡不成蚀把米的滑稽行径已成为国际笑柄。南海是和平之海，美丽而平静，请美军不要随意乱丢垃圾！
# Location Sentence: 不过，打捞战机并非易事，而是一项“艰巨的任务”。英国战机坠海后，英、美、意三国联手，花了2周才确定战机在海底的位置，又花了1周才成功将残骸打捞出水。
# Nationality Sentence: 美军会直接炸毁坠入南海的F35C战机？美媒：不太可能-上游新闻
# Date Sentence:
#
# Ship Name: 里根
# Location:
# Nationality: 韩国
# Date: 2022-08-02
# File Name: File number 79
# Ship Sentence: 台媒：美航母“里根号”将护送佩洛西专机抵台
# Location Sentence:
# Nationality Sentence: 据台湾中时新闻网报道，美国众议院议长佩洛西正在访问亚洲，其办公室公布确定行程包含新加坡、马来西亚、日本、韩国等国家。至于是否访台，报道称，目前传出最新消息称，佩洛西预计将在8月2日晚上10时30分抵达松山机场，并入住台北君悦酒店，3日上午8时与民进党当局领导人蔡英文会面，随后于上午10时离台。
# Date Sentence:
#
# Ship Name: 里根
# Location: 宫古海峡
# Nationality: 美国
# Date: 2023-06-24
# File Name: File number 80
# Ship Sentence: “里根”号在南海活动。图源：美国海军学会新闻网
# Location Sentence: 基于这一判断，我认为，美国主动在南海挑事，仍然是把南海问题当成了工具和手段，其目的仍然是在为未来的“台海战争”在布局。美国强化美澳同盟为澳大利亚建造核动力潜艇，其目的是为了从台湾东面的太平洋上封锁台海，美国再造美日军事同盟，其目的是为了利用日本封锁解放军从宫古海峡进出太平洋与包抄台湾的通道，明白了这一点我们就可以知道，美国再度炒作南海问题，在菲律宾增加四个军事基地，则是为了从南面封锁中国大陆海军进出巴士海峡包抄台湾的通道。而美国最近频频向越南招手，强化美越两国的军事关系，则不仅是为了强化美军在南海的军事存在，利用南海来包抄台海，而且不排除是想通过挑起南海纷争的方式，来围魏救赵，牵制和化解台海的紧张局势。
# Nationality Sentence: “里根”号在南海活动。图源：美国海军学会新闻网
# Date Sentence:
#
# Ship Name: 里根
# Location: 马六甲海峡
# Nationality: 中国
# Date: 2023-02-20
# File Name: File number 81
# Ship Sentence: 在央视披露山东号航母在南海对美海军进行中英文双语喊话后，美国海军尼米兹号航母打击群便高速撤离南海地区，这是尼米兹号航母打击群第二次撤出南海地区，可以说美航母打击群前后2次高速撤离一反常态。尼米兹号航母是去年年底，美国海军派来顶班进入横须贺修整的里根号航母的，尼米兹号航母于今年1月12日，在3艘阿利伯克级导弹驱逐舰的护卫下进入南海地区。
# Location Sentence: 解放军立即组织海空兵力全程监视，没想到在南海仅仅不到3天，尼米兹号航母就以25节的高速向西驶离快速脱离南海地区，进入到马六甲海峡附近。美航母匪夷所思的举动，实际上就是美国航母为了摆脱中国海军舰艇的监视而采取高速脱离的战术，因为此前美国卡尔文森号航母战斗群指挥官就曾经表示，如果美海军航母在南海保持非常规姿态高速航行，那就是要摆脱解放军054A护卫舰的监视。现在由于解放军海空实力的不断加强，054A等先进战舰基本上是在南海监视美国海军的常客。
# Nationality Sentence: 中国造船能力是美国200倍
# Date Sentence:
#
# Ship Name: 军
# Location: 南沙群岛
# Nationality: 美
# Date: 2016-05-06
# File Name: File number 82
# Ship Sentence: 中国海军6艘主力舰开赴南海
# Location Sentence: 不少外媒把这次年度例行训练与南海局势联系起来。新加坡《联合早报》5日称，南海仲裁案宣判在即，中国在南海再有动作，以表明自身立场。中国海军4日开启战备巡逻远海实兵对抗训练，编队分为三个兵力群，分赴南海、东印度洋、西太平洋生疏海域进行训练。“有意思的是，南沙群岛和西沙群岛的守备部队也将参加此次军演”，《外交学者》称，中国一直在扩大西沙群岛最大岛屿永兴岛上的军事存在，并扩大在南沙群岛的军事存在。目前尚不清楚驻守在这些岛屿的守备部队如何参加演练。
# Nationality Sentence: 美认为先进舰艇媲美西方_新闻频道_央视网(cctv
# Date Sentence:
#
# Ship Name: A
# Location: 南海诸岛
# Nationality: 中国
# Date: None
# File Name: File number 83
# Ship Sentence: 不远处出现我军054A护卫舰
# Location Sentence: /></i></p><p>对于美国海军驱逐舰近日在南海的活动情况，解放军南部战区在3月11日进行了回应。</p><p>南部战区新闻发言人李华敏大校表示，3月10日，美军“麦克坎贝尔”号导弹驱逐舰擅自闯入中国西沙领海。中国人民解放军南部战区组织海空兵力全程对其跟踪监视、查证识别，并予以警告驱离。美方打着“航行自由”的幌子，一而再、再而三地在南海秀肌肉、挑衅滋事。这是违反国际法规则的霸权行径，是威胁南海地区和平稳定的祸乱之源。中国对南海诸岛及其附近海域拥有无可争辩的主权，中国军队时刻保持高度戒备，采取一切必要措施，坚决捍卫国家主权安全，坚决维护南海地区和平稳定。</p><p><i
# Nationality Sentence: data-type="rtext"><p>【环球网军事报道】据美国国防部3月10日发布的消息，美国海军“麦克坎贝尔”号驱逐舰当天在中国南海海域航行，在美军发布的现场画面中，美国军舰不远处出现了一艘中国海军054A型护卫舰的身影。</p><p><i
# Date Sentence:
#
# Ship Name: 里根
# Location:
# Nationality: 美国
# Date: None
# File Name: File number 84
# Ship Sentence: 美国新航空母舰“里根号”正式命名
# Location Sentence:
# Nationality Sentence: 美国新航空母舰“里根号”正式命名
# Date Sentence:
#
# Ship Name: 罗斯福
# Location: 的海域
# Nationality: 美国
# Date: None
# File Name: File number 85
# Ship Sentence: data-desc="【环球网军事综合报道】据路透社11日报道，美国“罗斯福”号核动力航空母舰打击群11日在主权争议不断的南海执行例行演练，在20分钟内，20架F-18战斗机在“罗斯福”号航空母舰上起降，强力展示美军的精确与效率。“罗斯福”号航空母舰打击群指挥官斯蒂芬·柯勒表示，“我们看到中国船舰在我们四周。他们是南海作业的各国海军之一，但我可以告诉大家，我们遇到的船舰谨守专业。”柯勒还称，“我们在南海及其附近海域或者任何我们行动的海域进行的所有活动，都有国际法起作用”。"></i></img><i
# Location Sentence: data-desc="【环球网军事综合报道】据路透社11日报道，美国“罗斯福”号核动力航空母舰打击群11日在主权争议不断的南海执行例行演练，在20分钟内，20架F-18战斗机在“罗斯福”号航空母舰上起降，强力展示美军的精确与效率。“罗斯福”号航空母舰打击群指挥官斯蒂芬·柯勒表示，“我们看到中国船舰在我们四周。他们是南海作业的各国海军之一，但我可以告诉大家，我们遇到的船舰谨守专业。”柯勒还称，“我们在南海及其附近海域或者任何我们行动的海域进行的所有活动，都有国际法起作用”。"></i></img><i
# Nationality Sentence: data-desc="【环球网军事综合报道】据路透社11日报道，美国“罗斯福”号核动力航空母舰打击群11日在主权争议不断的南海执行例行演练，在20分钟内，20架F-18战斗机在“罗斯福”号航空母舰上起降，强力展示美军的精确与效率。“罗斯福”号航空母舰打击群指挥官斯蒂芬·柯勒表示，“我们看到中国船舰在我们四周。他们是南海作业的各国海军之一，但我可以告诉大家，我们遇到的船舰谨守专业。”柯勒还称，“我们在南海及其附近海域或者任何我们行动的海域进行的所有活动，都有国际法起作用”。"></i></img><i
# Date Sentence:
#
# Ship Name: 文森
# Location:
# Nationality: 中国
# Date: 2022-01-12
# File Name: File number 86
# Ship Sentence: 根据观察者网1月12日的报道，知名南海问题博主南海战略势态感知发布消息，美国“卡尔文森”号航母以及“埃塞克斯”号两栖戒备大队在11日从两个方向进入南海地区。这也是2022年美国航母打击队第一次进入南海地区，距离上次在南海出现已经过去近三个月，在此期间南海一直是风平浪静。
# Location Sentence:
# Nationality Sentence: 不过，美国这思想进步也太慢了，现在还想着搞航母威胁，有些太看不起中国这些年的发展成果了。别说两个航母战斗群，就是三个四个又能够有多大的作用，这个东西也就是能够吓唬吓唬小国家，中国现在还真的就不怕。
# Date Sentence:
#
# Ship Name: 美军
# Location: 西沙领海
# Nationality: 美国
# Date: 2022-01-21
# File Name: File number 87
# Ship Sentence: 2022年美军舰首次在南海进行挑衅行动，中国军方严厉敲打
# Location Sentence: 1月20日，解放军南部战区新闻发言人率先披露，当日美军舰擅闯中国西沙领海。当天中国国防部新闻发言人也就此事发表谈话。南部战区和国防部先后以“谈话”形式发布信息，表明了解放军的立场，对美挑衅行动进行严厉敲打，要求美方立即停止此类挑衅行径。
# Nationality Sentence: 美方还是一贯的说辞。美国第7舰队公共事务部在一则声明中声称，“中国关于这次任务的说法不实。”声明称，当时“本福德”号正进行“符合国际法”的航行自由作业，之后该军舰继续在国际海域进行正常作业。“美国正在捍卫每个国家在国际法容许下的飞行、航行和作业权利，一如
# Date Sentence:
#
# Ship Name: 里根
# Location: 朝鲜半岛
# Nationality: 中国
# Date: 2023-04-22
# File Name: File number 88
# Ship Sentence: 由于舰龄普遍在几十年，该型航母的故障率越来越高，其大修时间也越来越久，根据美国海军的部署，一艘尼米兹级航母的大修时间理应在半年左右，但在最近几年，尼米兹号，林肯号以及肯尼迪号等航母的大修时间普遍达到了一年甚至超过了一年之久，由于航母大修时间超出预估，其他航母的部署时间不得不延长，在去年，里根号航母的部署时间就首次超过了12个月，超期部署也让航母老化的程度越来越快。
# Location Sentence: 最近一段时间以来，东亚地区的安全形势变得越来越严峻，在台海地区，美国从去年开始就一直在试图挑战中国底线，不仅与台湾当局往来密切，同时还多次为其提供武器，违反一个中国政策，而在朝鲜半岛，美韩之间也在不断加大对朝鲜的施压力度，导致朝鲜连续试射导弹，使战争爆发的可能性大幅增加。除了这两个地区以外，南海地区近期也并不太平，而美国也同样与之有关。
# Nationality Sentence: 最近一段时间以来，东亚地区的安全形势变得越来越严峻，在台海地区，美国从去年开始就一直在试图挑战中国底线，不仅与台湾当局往来密切，同时还多次为其提供武器，违反一个中国政策，而在朝鲜半岛，美韩之间也在不断加大对朝鲜的施压力度，导致朝鲜连续试射导弹，使战争爆发的可能性大幅增加。除了这两个地区以外，南海地区近期也并不太平，而美国也同样与之有关。
# Date Sentence:
#
# Ship Name: 斯坦塞姆
# Location: 西沙群岛
# Nationality: 美国
# Date: 2017-07-03
# File Name: File number 89
# Ship Sentence: 据外电报道，7月2日，美国“斯坦塞姆”号导弹驱逐舰进入中国西沙群岛中建岛12海里领海。中国外交部发言人陆慷2日就此表示，美军驱逐舰擅自进入中国西沙群岛领海，中国随即派出军舰和战斗机对美舰实施警告驱离。中方强烈敦促美方立即停止此类严重侵犯中国主权、威胁中国安全的挑衅行动。中方将继续采取一切必要措施捍卫国家主权和安全。
# Location Sentence: 据外电报道，7月2日，美国“斯坦塞姆”号导弹驱逐舰进入中国西沙群岛中建岛12海里领海。中国外交部发言人陆慷2日就此表示，美军驱逐舰擅自进入中国西沙群岛领海，中国随即派出军舰和战斗机对美舰实施警告驱离。中方强烈敦促美方立即停止此类严重侵犯中国主权、威胁中国安全的挑衅行动。中方将继续采取一切必要措施捍卫国家主权和安全。
# Nationality Sentence: 据外电报道，7月2日，美国“斯坦塞姆”号导弹驱逐舰进入中国西沙群岛中建岛12海里领海。中国外交部发言人陆慷2日就此表示，美军驱逐舰擅自进入中国西沙群岛领海，中国随即派出军舰和战斗机对美舰实施警告驱离。中方强烈敦促美方立即停止此类严重侵犯中国主权、威胁中国安全的挑衅行动。中方将继续采取一切必要措施捍卫国家主权和安全。
# Date Sentence:
#
# Ship Name: 里根
# Location: 相关海域
# Nationality: 美国
# Date: 2022-08-05
# File Name: File number 90
# Ship Sentence: 里根号航母搭载多少架飞机是什么级别的是核动力航母吗？里根号配置战斗力如何_军事频道_中华网
# Location Sentence: 据韩联社报道，美国海军研究所11日表示，美国海军的“亚伯拉罕·林肯”号核动力航空母舰当天已驶入韩国东部的日本海。这是美航母时隔4年零5个月后，再次现身相关海域。
# Nationality Sentence: Reagan，舷号：CVN-76，全称：罗纳德·里根号航空母舰），是20世纪90年代末期美国建造的尼米兹级航空母舰的9号舰，也是美国在进入21世纪以后第一艘入役的航空母舰。
# Date Sentence:
#
# Ship Name: 里根
# Location: 附近水域
# Nationality: 美
# Date: 2023-06-26
# File Name: File number 91
# Ship Sentence: “里根”号的到来折射出美越双方的战略考量。
# Location Sentence: 另据美国海军研究学会消息，美国海军的这三艘军舰以及“拉斐尔·佩拉尔塔”号驱逐舰已在南海附近水域活动了一个多星期。
# Nationality Sentence: 微妙时刻，美国核动力航母罕见停靠越南
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 停靠港口
# Nationality: 美
# Date: 2023-06-30
# File Name: File number 92
# Ship Sentence: “林肯”号属于美国海军“尼米兹”级航母，满载排水量约10万吨，可携带E-2D、F/A-18E/F等舰载机，载机数量超过70架，通常包括4个攻击战斗机中队、1个预警机中队、1个电子战飞机中队、1个后勤保障中队和2个直升机中队。
# Location Sentence: 停靠港口的“林肯”号航母。
# Nationality Sentence: 美“林肯”号核航母再次发生火灾，去年火灾致六人受伤
# Date Sentence:
#
# Ship Name: 里根
# Location: 附近水域
# Nationality: 美
# Date: 2023-06-26
# File Name: File number 93
# Ship Sentence: “里根”号的到来折射出美越双方的战略考量。
# Location Sentence: 另据美国海军研究学会消息，美国海军的这三艘军舰以及“拉斐尔·佩拉尔塔”号驱逐舰已在南海附近水域活动了一个多星期。
# Nationality Sentence: 微妙时刻，美国核动力航母罕见停靠越南
# Date Sentence:
#
# Ship Name: 里根
# Location:
# Nationality: 中国
# Date: 2018-02-08
# File Name: File number 94
# Ship Sentence: 又曝丑闻！美“里根号”航母船员涉性侵在东京被捕-新华网
# Location Sentence:
# Nationality Sentence: 巴西黄热病死亡人数升至９８人津巴布韦已发行近３亿美元债券货币今年多赚了三四万——“羊馆”武小斌的网路卖羊记委内瑞拉将于４月２２日举行总统选举韩国大叔失联30年的中国朋友新华网评：过年方式变迁，“年味”从未走远朝鲜表示访韩代表团无意与美方会面广东佛山地铁施工路段发生地面塌陷
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: 美国
# Date: 2022-01-23
# File Name: File number 95
# Ship Sentence: 美媒盘点世界各国航母实力｜美国：“尼米兹”级和“福特”级航母
# Location Sentence:
# Nationality Sentence: 美媒盘点世界各国航母实力｜美国：“尼米兹”级和“福特”级航母
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 海湾地区
# Nationality: 美国
# Date: 2013-09-03
# File Name: File number 96
# Ship Sentence: 美国尼米兹号核动力航母战斗群正驶向红海-中新网
# Location Sentence: “尼米兹”号航母战斗群先前在印度洋执行任务，负责对美国在阿富汗的军事行动提供支持。根据美军在海湾地区维持单航母配置的计划，“尼米兹”号近期由“哈里・S・杜鲁门”号核动力航空母舰接替，原计划向东行驶，经太平洋返回在华盛顿州埃弗里特的港口。
# Nationality Sentence: 美国尼米兹号核动力航母战斗群正驶向红海-中新网
# Date Sentence:
#
# Ship Name:
# Location: 邻近海域
# Nationality: 中国
# Date: 2018-03-24
# File Name: File number 97
# Ship Sentence:
# Location Sentence: [北京您早]美军舰进入我南海岛礁邻近海域_新闻频道_央视网(cctv
# Nationality Sentence:
# Date Sentence:
#
# Ship Name: 文森
# Location: 南海海域
# Nationality: 中国
# Date: 2018-04-03
# File Name: File number 98
# Ship Sentence: 由于此前在第七舰队执勤的航母卡尔·文森号以及离开横须贺军港，回到本土，罗斯福所在的第九航母打击大队将接替卡尔文森号航母，作为第七舰队的航母进行战备执勤任务。
# Location Sentence: 综合报道】据美国海军官方网站宣布，“罗斯福”号航母为旗舰的第九航母打击大队目前已经离开新加坡，并于北京时间4月3日进入南海海域。而根据此前的消息，中国海军在南海举行大规模军事演习，有包括“辽宁”舰在内的40多艘舰艇参加。
# Nationality Sentence: 针对中国南海大演习
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: 美国
# Date: 2017-09-06
# File Name: File number 99
# Ship Sentence: 美国的核动力航母按搭载80架飞机计算，每架飞机出动一次平均油耗10吨。假设每架飞机一天出动一次，那么消耗的燃料就在800吨左右，而尼米兹级航母一般可以携带9000吨的航空燃料，按照这样的油耗只能维持8-12天的作战需求。如果补给舰被击沉，相当于航母编队的持续作战能力下降百分之五十，甚至百分之百。
# Location Sentence:
# Nationality Sentence: 美国的核动力航母按搭载80架飞机计算，每架飞机出动一次平均油耗10吨。假设每架飞机一天出动一次，那么消耗的燃料就在800吨左右，而尼米兹级航母一般可以携带9000吨的航空燃料，按照这样的油耗只能维持8-12天的作战需求。如果补给舰被击沉，相当于航母编队的持续作战能力下降百分之五十，甚至百分之百。
# Date Sentence:
#
# Ship Name: 华盛顿
# Location: 南中国海
# Nationality: 美国
# Date: 2016-03-04
# File Name: File number 100
# Ship Sentence: 据悉，美国军官透露，“斯坦尼斯”号航空母舰是1月15日从华盛顿州（布雷默顿基地）出发的，该舰与两艘驱逐舰、两艘巡洋舰和第七舰队旗舰一起，于最近几天内前往南中国海争议海域。
# Location Sentence: 美国《防务新闻》网站3月3日报道，美国海军派遣了一支规模虽小但实力强大的舰队前往南中国海。据报道，前往南海的是以“斯坦尼斯”号航母为核心的打击大队，包括“斯坦尼斯”号航母、“安提坦”号、“莫比尔湾”号两艘“提康德罗加”级导弹巡洋舰；“钟云”、“斯托克顿”号两艘“阿利·伯克”级驱逐舰，此外第七舰队旗舰“蓝岭”号指挥舰在前往菲律宾访问途中将与这支舰队编队行动。美媒称，这个航母打击大队是对局势紧张的南海地区最新的一次“力量展示”，美国声称中国正为“实现自己的领土要求”，正对这一地区进行“军事化”。
# Nationality Sentence: 美国海军南海南沙岛礁建设
# Date Sentence:
#
# Ship Name: 华盛顿
# Location: 南海海域
# Nationality: 日本
# Date: 2009-06-15
# File Name: File number 101
# Ship Sentence: 从2001年开始就常驻东亚，其母港为日本横须贺，隶属美军第7舰队第5航母打击群第15驱逐舰中队，是美军航空母舰的“贴身警卫”。2008年9月“华盛顿”号航母抵达东亚部署后，“约翰・麦凯恩”号导弹驱逐舰一直伴随其左右。
# Location Sentence: 报道称，事件发生的地点位于菲律宾苏比克湾附近的南海海域，所幸中美舰艇本身没有相撞。据了解，该海域实际位于中沙黄岩岛与苏比克湾之间，黄岩岛距菲律宾苏比克湾距离仅为100海里左右。
# Nationality Sentence: 从2001年开始就常驻东亚，其母港为日本横须贺，隶属美军第7舰队第5航母打击群第15驱逐舰中队，是美军航空母舰的“贴身警卫”。2008年9月“华盛顿”号航母抵达东亚部署后，“约翰・麦凯恩”号导弹驱逐舰一直伴随其左右。
# Date Sentence:
#
# Ship Name: 蓝岭
# Location: 南海海域
# Nationality: 中国
# Date: 2014-05-08
# File Name: File number 102
# Ship Sentence: 中美军舰中美军舰南海对峙中美军舰南海相遇第七舰队蓝岭号第七舰队海洋维权
# Location Sentence: 2014年5月5日，中国海军一艘054A级新型护卫舰572衡水舰，一艘052C级驱逐舰170兰州舰，与美国海军第七舰队旗舰LCC19蓝岭号指挥舰，在中国南海海域遭遇。美舰随即起飞MH-
# Nationality Sentence: 美第七舰队旗舰直升机跟拍中国编队
# Date Sentence:
#
# Ship Name: 里根
# Location: 台湾海峡
# Nationality: 中国
# Date: 2022-08-19
# File Name: File number 103
# Ship Sentence: 美军“里根号”航母返回日本母港，曾被传将穿越台湾海峡
# Location Sentence: 美军“里根号”航母返回日本母港，曾被传将穿越台湾海峡
# Nationality Sentence: 美国众议院议长佩洛西于8月2日至3日窜访台湾地区后，中国人民解放军进行了台海军演。期间，以“里根号”为核心的第五航母打击群在台湾东南的菲律宾附近海域执行任务。
# Date Sentence:
#
# Ship Name: 里根
# Location: 香港水域
# Nationality: 中国
# Date: 2018-11-21
# File Name: File number 104
# Ship Sentence: 美国里根号航母进入香港水域
# Location Sentence: 美国里根号航母进入香港水域
# Nationality Sentence: Reagan，CVN76）今日访问中国香港，目前已正式进入香港附近水域。
# Date Sentence:
#
# Ship Name: 尼米兹
# Location: 红海海域
# Nationality: 美国
# Date: 2013-09-04
# File Name: File number 105
# Ship Sentence: 美国“尼米兹”号航母红海待命-中新网
# Location Sentence: 美国海军网站发布消息，当地时间9月3日，由尼米兹号核动力航母，普林斯顿号巡洋舰和三艘伯克级驱逐舰构成的尼米兹号航母战斗群进入红海海域的第五舰队任务区开始进行部署。
# Nationality Sentence: 美国“尼米兹”号航母红海待命-中新网
# Date Sentence:
#
# Ship Name: 里根
# Location: 敌方沿岸
# Nationality: 美
# Date: 2007-08-23
# File Name: File number 106
# Ship Sentence: 此外，这还取决于国家的总体实力强弱与军费投入的多少。现代大型航母无疑是一个巨大的“吞金兽”，例如美尼米兹级“里根”号核动力航母的建造费为45亿美元，而新一代CVN78的建造费用更高达80亿美元。大型航母如此高额的费用对于一些小国来说简直就是天方夜谭。泰国2004年的全部军费预算不过19亿美元，即使全部拨给海军，还不够建造半艘尼米兹级航母。
# Location Sentence: 同时，美海军认为，在未来15年内，美海军大规模的海上作战将越来越少。美军今后面临的主要威胁是局部地区冲突对美国利益构成的损害以及针对美国本土与海外盟国的恐怖袭击等。随着美海外基地的减少，兵力前沿部署将逐步转变为兵力快速前沿投送，并迅速控制态势，对敌形成威慑。而现代海军高技术的巡航导弹、弹道导弹、舰载机、火炮等武器装备已具有对敌方沿岸及陆地纵深1500公里范围内的目标实施精确打击的能力。基于这种认识，美海军战略由“远洋作战”转变为“由海向陆作战”，即美军海上力量未来的作战行动将主要在近海区域进行，重点对陆上目标发动打击。与大型航母相比，小型航母在实现“由海向陆”作战方面将具备更多的优势。因为小型航母吃水浅，行动更加灵活方便，而且建造费用小，可装备数量更多。
# Nationality Sentence: com-美国新航母：个头更大
# Date Sentence:
#
# Ship Name: 里根
# Location: 南沙群岛
# Nationality: 中国
# Date: 2020-09-29
# File Name: File number 107
# Ship Sentence: 上半年，美军在中国南海地区先后派出“罗斯福”号、“里根”号、“尼米兹”号航母；同时，美军侦察机、舰艇来南海地区对我国海岸频繁抵近巡航。美国当局却“贼喊捉贼”，倒打一耙，称我国在南海地区“军事化”。
# Location Sentence: 9月26日，美国国务院发表声明，无端指责中国“违背了无意在南沙群岛搞军事化的承诺，大搞挑衅性的南海军事化”。
# Nationality Sentence: 上半年，美军在中国南海地区先后派出“罗斯福”号、“里根”号、“尼米兹”号航母；同时，美军侦察机、舰艇来南海地区对我国海岸频繁抵近巡航。美国当局却“贼喊捉贼”，倒打一耙，称我国在南海地区“军事化”。
# Date Sentence:
#
# Ship Name: 里根
# Location:
# Nationality: 中国
# Date: 2022-07-28
# File Name: File number 108
# Ship Sentence: 有记者提问：近日，美国海军“里根”号航母打击群再次进入南海游弋，请问中方对此有何评论？
# Location Sentence:
# Nationality Sentence: 中国新闻网
# Date Sentence:
#
# Ship Name: 核潜艇
# Location:
# Nationality: 美国
# Date: 2022-08-05
# File Name: File number 109
# Ship Sentence: 国防大学教授孟祥青介绍：此次台海演习，①航母编队首次威慑性演练，核潜艇参演，构建了海上立体式的作战体系；②首次在台岛以东设置靶场，将当时给佩洛西护航的美国“里根”号航空母舰，逼退约几百公里。
# Location Sentence:
# Nationality Sentence: 国防大学教授孟祥青介绍：此次台海演习，①航母编队首次威慑性演练，核潜艇参演，构建了海上立体式的作战体系；②首次在台岛以东设置靶场，将当时给佩洛西护航的美国“里根”号航空母舰，逼退约几百公里。
# Date Sentence:
#
# Ship Name: 米利厄斯
# Location: 西沙领海
# Nationality: 美
# Date: 2023-03-23
# File Name: File number 110
# Ship Sentence: 赵磊）记者从中国人民解放军南部战区新闻发言人田军里空军大校处获悉，3月23日，美“米利厄斯”号导弹驱逐舰未经中国政府批准，非法闯入中国西沙领海，破坏南海地区和平稳定，中国人民解放军南部战区组织海空兵力依法进行跟踪监视并予以警告驱离。
# Location Sentence: 赵磊）记者从中国人民解放军南部战区新闻发言人田军里空军大校处获悉，3月23日，美“米利厄斯”号导弹驱逐舰未经中国政府批准，非法闯入中国西沙领海，破坏南海地区和平稳定，中国人民解放军南部战区组织海空兵力依法进行跟踪监视并予以警告驱离。
# Nationality Sentence: 南部战区组织海空兵力警告驱离美军舰
# Date Sentence:
#
# Ship Name: 里根
# Location: 太平洋海域
# Nationality: 美国
# Date: 11月15日-11
# File Name: File number 111
# Ship Sentence: 又来一艘!里根号航母密集演习
# Location Sentence: 年11月15日刊发题为“罗纳德-里根号航母完成合成训练部队演习”的报道。报道称，此次演习大大提高了整个里根号航母打击群的协同战斗力，正开始准备进行联合特遣部队演习；里根号航母打击群正准备按计划在2011年到西太平洋进行例行部署，这也是六年来的第五次部署。里根号航母指挥官伯克说：这支舰队正准备前往地球的另一侧，或许是在一个相当紧张的时刻（前往）。</p><p>报道称，11月14日，罗纳德-里根号（CVN-76）航母及其搭载的第14舰载机联队(CVW-14)在太平洋海域成功完成了合成训练部队演习(COMPTUEX)，此次训练和演习为期3个周，目的是为即将来临的部署做好准备。此次合成训练部队演习是罗纳德-里根号航母打击群（CSG）“相互部署训练周期”(IDTC)的中间阶段；相互部署训练周期旨在与其他打击群相互磨砺作战技能，保持部队的战斗熟练度。</p>
# Nationality Sentence: CVN-76）是美国尼米兹级核动力航空母舰的九号舰，
# Date Sentence:
#
# Ship Name: 里根
# Location: 附近海域
# Nationality: 中国
# Date: 2011-03-14
# File Name: File number 112
# Ship Sentence: 里根号航母穿过放射云
# Location Sentence: 北京时间3月11日13点46分，日本本州岛附近海域发生里氏9
# Nationality Sentence: 士兵核辐射中暴露1小时--中国广播网
# Date Sentence:
#
# Ship Name: 官方
# Location: 南海诸岛
# Nationality: 美
# Date: 2022-11-29
# File Name: File number 113
# Ship Sentence: 19:05环球网官方帐号
# Location Sentence: 南部战区新闻发言人田军里空军大校29日表示，美军行径严重侵犯中国主权和安全，是其大搞航行霸权、制造南海军事化的又一铁证，充分说明美是不折不扣的南海安全风险制造者。中国对南海诸岛及其附近海域拥有无可争辩的主权，战区部队时刻保持高度戒备状态，坚决捍卫国家主权安全和南海地区和平稳定。
# Nationality Sentence: 我军首次披露美舰闯我海域航迹图，“精准高效才会让闯入者知难而退”
# Date Sentence:
#
# Ship Name: 尼米兹
# Location:
# Nationality: 美国
# Date: None
# File Name: File number 114
# Ship Sentence: 除去今年2月刚刚退役的“企业”号，美国目前拥有10艘现役航母，均为“尼米兹”级，10艘也是原本计划的总数量。但是“尼米兹”级自1975年以来已经服役超过40年，对新技术的支持有限，尤其早期建造的部分更存在超期服役问题。美国智库兰德即评价称，“尼米兹”级如今面临最大的问题是发电能力有限，以及改造升级后导致的重量增加和重心稳定性问题。“福特”级也正是在此背景下开发而来。
# Location Sentence:
# Nationality Sentence: 福特级承载美国影响力期望
# Date Sentence:
#
# Ship Name: 里根
# Location: 附近海域
# Nationality: 中国
# Date: 2023-06-25
# File Name: File number 115
# Ship Sentence: 据台湾“中时新闻网”报道，日前，美军“里根号”航母打击群出现在南海附近海域，中方出动至少5艘军舰，从四个方向实现“包围”态势。此外，解放军“轰-6K”战略轰炸机贴海飞行近300公里，对美军“里根号”进行驱离。台军退役少将栗正杰表示，“轰-6K”对“里根号”航母打开火控雷达，逼使其90度大回转，显示中国大陆在南海地区已经对美军形成极大军事威慑。
# Location Sentence: 据台湾“中时新闻网”报道，日前，美军“里根号”航母打击群出现在南海附近海域，中方出动至少5艘军舰，从四个方向实现“包围”态势。此外，解放军“轰-6K”战略轰炸机贴海飞行近300公里，对美军“里根号”进行驱离。台军退役少将栗正杰表示，“轰-6K”对“里根号”航母打开火控雷达，逼使其90度大回转，显示中国大陆在南海地区已经对美军形成极大军事威慑。
# Nationality Sentence: 中国青年网
# Date Sentence:
#
# Ship Name: 里根
# Location: 西沙群岛
# Nationality: 美国
# Date: 2019-09-27
# File Name: File number 116
# Ship Sentence: 国防部9月26日举行9月例行记者会，国防部新闻局副局长、国防部新闻发言人任国强大校主持。会上有记者提问称，据外媒报道，国外卫星照片显示，美国“里根”号航母正在南海航行。在“里根”号航母周围出现不少疑似中国军舰的船只。请问能否证实？
# Location Sentence: 美舰擅闯我西沙群岛领海
# Nationality Sentence: 美国航母进出南海周围出现多艘中国军舰？国防部回应
# Date Sentence:
#
# Ship Name: 里根
# Location: 南中国海
# Nationality: 美
# Date: 2015-10-30
# File Name: File number 117
# Ship Sentence: 美航母“里根”号在日本海与俄机对峙
# Location Sentence: 近期国内多家媒体报道称美国“里根”号航母可能到南中国海支持了几天前的接近美舰中国岛礁航行行动，这一消息并不属实。据29日最新报道，美国“里根”号航空母舰在朝鲜半岛以东海域与韩国海军联合训练期间，有俄罗斯图-142海上反潜巡逻机接近该舰，与美军紧急起飞的F/A-18战斗机对峙后飞离。
# Nationality Sentence: 美航母“里根”号在日本海与俄机对峙
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 附近海域
# Nationality: 美国
# Date: 2020-07-06
# File Name: File number 118
# Ship Sentence: B-52H轰炸机和洲际导弹、战略核潜艇一起，被视为美国的三大核载具，最多可挂载31吨炸药飞行超过6400公里，可单独执行任务。B-52是美军轰炸机部队的骨干机型，已经有60多年的历史，美军预计将使用B-52轰炸机至2050年。
# Location Sentence: B-52H重返关岛更多体现了美军“动态武力运用”的作战概念，其目的是使重大军事部署变得不易预测，以便让潜在对手紧张不安。可以预测，重返关岛的B-52H战略轰炸机将会在南海、东海附近海域实施巡航行动，展示肌肉。
# Nationality Sentence: 美国B-52H轰炸机在双航母南海巡航时重回关岛，中国专家：绝对不是巧合_新闻频道_央视网(cctv
# Date Sentence:
#
# Ship Name: 核潜艇
# Location: 周边海域
# Nationality: 美国
# Date: 2022-01-03
# File Name: File number 119
# Ship Sentence: 据悉，在2021年一整年，美军航母打击群和两栖戒备群达到南海海域的次数达到了13次，比去年增长了一倍，另外还有11艘核潜艇也进入到南海及其周边，在南海北部美国的两艘舰艇还发生了“撞山”事件，当时事故发生之后，美国甚至都未进行一个合理的解释。
# Location Sentence: 从今年开始，中国的周边海域均受到外来势力的挑衅，海上局势一度变得紧张，除了台海比较受关注之外，南海地区也在遭受着挑战。美国近些年来为了遏制中国的发展，时常介入中国周边的海上局势，特别是南海，频繁派遣军舰在南海挑衅。
# Nationality Sentence: 从今年开始，中国的周边海域均受到外来势力的挑衅，海上局势一度变得紧张，除了台海比较受关注之外，南海地区也在遭受着挑战。美国近些年来为了遏制中国的发展，时常介入中国周边的海上局势，特别是南海，频繁派遣军舰在南海挑衅。
# Date Sentence:
#
# Ship Name: 里根
# Location:
# Nationality: 美国
# Date: 2019-09-27
# File Name: File number 120
# Ship Sentence: 有记者提问，据外媒报道，国外卫星照片显示，美国“里根”号航母正在南海航行。在“里根”号航母周围出现不少疑似中国军舰的船只。请问能否证实？
# Location Sentence:
# Nationality Sentence: 美国航母进南海，周围出现多艘中国军舰？解放军回应来了
# Date Sentence:
#
# Ship Name: 里根
# Location: 越南港口
# Nationality: 越南
# Date: 2023-06-26
# File Name: File number 121
# Ship Sentence: 王逸】由“罗纳德·里根”号核动力航母（以下简称“里根”号航母）和两艘护航巡洋舰组成的美国海军舰艇编队25日停靠越南岘港市仙沙港，开始对越南进行为期5天的访问。据越通社25日报道，这是越南第三次迎来美国航母，前两次分别在2018年和2020年。“里根”号航母对岘港的访问是越美全面伙伴关系建立10周年庆祝活动的一部分。美联社23日报道称，华盛顿将河内视为其地区战略的关键组成部分，并一直寻求利用越南来扩大美国在该地区的影响力。
# Location Sentence: 作为美国海军最大的军舰之一，美联社将“里根”号航母停靠越南港口称作“罕见的访问”。据报道，“里根”号航母的基地位于日本横须贺，是唯一一艘前沿部署的美国航母。它将于明年被同为尼米兹级航母的“乔治·华盛顿”号航母取代。
# Nationality Sentence: 美国航母罕见停靠越南岘港，外媒炒“应对中国不断增强的实力”-荆楚网-湖北日报网
# Date Sentence:
#
# Ship Name: 里根
# Location: 西沙群岛
# Nationality: 美国
# Date: 2016-03-05
# File Name: File number 122
# Ship Sentence: “航行自由项目”是美国国务院、国防部和一线部队等多部门联合执行的行动计划。该计划有着详细而完整的标准和程序，只要政府高层决定就可以按照程序启动。FON项目的文件于1982年由里根政府签署并实施，并在之后的实践中逐步完善。根据美国国务院已经公开的文件，美国实施该计划旨在在全球范围应对六大类“不符合《联合国海洋法公约》（以下简称公约）”的所谓“过度海洋主张”（excessive
# Location Sentence: 今年3月1日，美国国防部长卡特在演说中强烈批评了中国在南海的军事部署，称““中国不应推进南海军事化……特定行为将产生特定的后果。”此番言论呼应了近几年来美国在南海愈加频繁的干涉行动。实际上，早在去年11月3日美“拉森”号驱逐舰驶入南沙群岛的渚碧礁12海里区域之后，美国防部官员就表示，美军计划每季度在南海“人造岛礁”12海里内巡航两次，以“提醒中国和其他国家尊重美国在国际法下的权益”。随后在今年1月30日，美“柯蒂斯·威尔伯”号驱逐舰就在未通知中方的情况下，进入西沙群岛的中建岛12海里区域内。这两次行动虽然在性质上并不相同，但同属于美国干涉其他国家海上权益争端的一个项目——“航行自由项目”（Freedom
# Nationality Sentence: 航行自由南海海洋公约美国军舰岛礁南海“执法”南海军事
# Date Sentence:
#
# Ship Name: 里根
# Location: 菲律宾海
# Nationality: 美国
# Date: 2021-03-04
# File Name: File number 123
# Ship Sentence: 但近年来，为了服务大国竞争，特别是加强对华威慑，美海军不少航母打击大队都在过度部署。如“尼米兹”号此次已经在海外部署了250余天，2020年，部署在西太前沿的“里根”号在海上也进行了近5个月的行动。美国海军学会网站的数据显示，2020年1月至10月，美军航母在海上行动的总天数高达855天，比2019年全年还多258天，不少航母海外部署的时间都创了纪录。在这种背景下，美军航母在南海及其周边活动的烈度肯定会上升。
# Location Sentence: 另外，我们之所以看到美军航母越来越频繁地进出南海，也与其新的部署方式有关。至少从2020年开始，美军航母在包括南海的西太平洋的行动不再如此前那样按部就班或进行一般意义上的巡航，而是常态化在菲律宾海巡航，针对南海、台海等热点区域，有事就快进快出，在南海停留时间有限，短则1日，长不过3～5日，并且加强与其他航母、轰炸机和加油机等兵力的联演联训。
# Nationality Sentence: 胡波：拜登上台后美国航母频繁进出南海，意欲何为？
# Date Sentence:
