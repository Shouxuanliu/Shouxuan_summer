# %%
from pyhanlp import *

# %%
import os

folder_name = input("Enter your foldername: ")

folder_path = "/Users/hutusheng/Desktop/database/"  + folder_name

report_texts = []

# Iterate over all files in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)

    # Check if the path is a file
    if os.path.isfile(file_path):
        with open(file_path, "r") as file:
            report_text = file.read()
            report_text = report_text.replace("账号","")
            report_texts.append(report_text)

# %%
import re
from pyhanlp import HanLP

def extract_named_entities(text):
    segment = HanLP.newSegment().enableNameRecognize(True)
    term_list = segment.seg(text)
    named_entities = []
    for term in term_list:
        if term.nature.toString() == "nr"or "nt":
            named_entities.append(term.word)
    return named_entities

def extract_name(named_entities):
    ship_keywords = [
    "号",
    "轮", 
    "船", 
    "舰", 
    "军舰",
    "号船", 
    "号轮", 
    "船只", 
    "舰艇", 
    "船舶", 
    "船只", 
    "货轮", 
    "客轮", 
    "油轮", 
    "潜艇", 
    "驳船", 
    "渡船", 
    "航母", 
    "货船", 
    "运输船",
    "航母",
    "航空母舰"
]

    for i in range(len(named_entities)):
        entity = named_entities[i]
        for keyword in ship_keywords:
            if keyword in entity:
                if i > 0 and entity=="号":
                    previous_entity = named_entities[i - 1]
                    return previous_entity 
                else:
                    return entity
    return ""



def extract_location(named_entities):
    location_keywords = [    
    "港湾",
    "港口",
    "海域",
    "海滩",
    "海湾",
    "海岸线",
    "海峡",
    "海底",
    "岸边",
    "河口",
    "岛屿",
    "航线",
    "码头",
    "航道",
    "海港",
    "水域",
    "水道",
    "河流",
    "湾区",
    "泊位",
    "湖泊",
    "湖区",
    "海上",
    "江口",
    "湖边",
    "沿海",
    "沿岸",
    "海路"]
    for i in range(len(named_entities)):
        entity = named_entities[i]
        for keyword in location_keywords:
            if keyword in entity:
                if i > 0 and keyword==entity:
                    previous_entity = named_entities[i - 1]
                    return previous_entity + entity
                else:
                    return entity
    return ""

def extract_nationality(named_entities, ship_name):
    country_mapping = {
    "中国": "中国",
    "美": "美国",
    "美国": "美国",
    "日本": "日本",
    "日": "日本",
    "韩国": "韩国",
    "韩": "韩国",
    "英国": "英国",
    "英": "英国",
    "加拿大": "加拿大",
    "德国": "德国",
    "法国": "法国",
    "印度": "印度",
    "巴西": "巴西",
    "墨西哥": "墨西哥",
    "俄罗斯": "俄罗斯",
    "意大利": "意大利",
    "西班牙": "西班牙",
    "荷兰": "荷兰",
    "瑞典": "瑞典",
    "挪威": "挪威",
    "丹麦": "丹麦",
    "芬兰": "芬兰",
    "爱尔兰": "爱尔兰",
    "奥地利": "奥地利",
    "瑞士": "瑞士",
    "新加坡": "新加坡",
    "马来西亚": "马来西亚",
    "印度尼西亚": "印度尼西亚",
    "泰国": "泰国",
    "越南": "越南",
    "菲律宾": "菲律宾",
    "南非": "南非",
    "埃及": "埃及",
    "肯尼亚": "肯尼亚"
}


    closest_entity = None
    min_distance = float('inf')

    for entity in named_entities:
        if entity and ship_name:
            for keyword in country_mapping.keys():
                if entity == keyword:
                    distance = abs(named_entities.index(ship_name) - named_entities.index(entity))
                    if distance < min_distance:
                        min_distance = distance
                        closest_entity = entity

    return closest_entity if closest_entity else ""

def extract_date(text):
    pattern = r"(\d{4})-(\d{2})-(\d{2})"
    pattern2 = r"(\d{4})年(\d{2})月(\d{2})日"
    match = re.search(pattern, text)
    match2 = re.search(pattern2, text)
    if match:
        year = match.group(1)
        month = match.group(2)
        day = match.group(3) if match.group(3) else None
        return f"{year}-{month.zfill(2)}-{day.zfill(2)}" if day else f"{year}-{month.zfill(2)}"
    elif match2:
        year = match2.group(1)
        month = match2.group(2)
        day = match2.group(3) if match2.group(3) else None
        return f"{year}-{month.zfill(2)}-{day.zfill(2)}" if day else f"{year}-{month.zfill(2)}"
    return None


import re

def extract_sentences(report_texts):
    result_dict_list = []

    for m, report_text in enumerate(report_texts):
        # Extract named entities
        named_entities = extract_named_entities(report_text)
        named_entities = [entity for entity in named_entities if entity.isalpha()]
        named_entities = [entity for entity in named_entities if entity and isinstance(entity, str)]


        # Extract ship name
        date = extract_date(report_text)

        pattern = r"(\d{4})-(\d{2})-(\d{2})"
        pattern2 = r"(\d{4})年(\d{2})月(\d{2})日"
        report_text = re.sub(pattern, '', report_text)
        report_text = re.sub(pattern2, '', report_text)
        # Extract location
        location = extract_location(named_entities)

        # Extract nationality
        ship_name = extract_name(named_entities)
        nationality = extract_nationality(named_entities, ship_name)
        
        # Extract date

        # Split report text into sentences
        sentences = re.split(r'[.,\s]+', report_text)

        ship_sentence = ""
        location_sentence = ""
        nationality_sentence = ""
        date_sentence = ""

        for sentence in sentences:
            if ship_name and ship_name in sentence and not ship_sentence:
                ship_sentence = sentence
            if location and location in sentence and not location_sentence:
                location_sentence = sentence
            if nationality and nationality in sentence and not nationality_sentence:
                nationality_sentence = sentence
            if date is not None and date in sentence and not date_sentence:
                date_sentence = sentence

            if ship_sentence and location_sentence and nationality_sentence and date_sentence:
                break

        result_dict = {
            "Ship Name": ship_name,
            "Location": location,
            "Nationality": nationality,
            "Date": date,
            "File Name": f"File number {m}",
            "Ship Sentence": ship_sentence,
            "Location Sentence": location_sentence,
            "Nationality Sentence": nationality_sentence,
            "Date Sentence": date_sentence
        }

        result_dict_list.append(result_dict)

    return result_dict_list

# %%
output=extract_sentences(report_texts)
print(output)
# Out:
# [{'Ship Name': '尼米兹', 'Location': '苏里高海峡', 'Nationality': '美', 'Date': '2023-02-20', 'File Name': 'File number 0', 'Ship Sentence': '美尼米兹号航母打击群驶离南海', 'Location Sentence': 'AIS信号显示，2月20日，尼米兹号航母打击群成员“迪云”号与“韦恩·迈耶”号驱逐舰经苏里高海峡进入菲律宾海。2月19日，打击群成员“迪卡特”号与“韦恩·迈耶”号驱逐舰在苏禄海活动，同日，一架美海军P-8A反潜巡逻机自菲律宾克拉克机场起飞，提供ISR(情报、侦察、监视)支援。据三艘驱逐舰航行轨迹推断，尼米兹号航母打击群已于2月18日自巴拉巴克海峡进入苏禄海，结束此次南海部署。', 'Nationality Sentence': '美尼米兹号航母打击群驶离南海', 'Date Sentence': ''}, {'Ship Name': '尼米兹', 'Location': '以东海域', 'Nationality': '日', 'Date': '2023-04-17', 'File Name': 'File number 1', 'Ship Sentence': '尼米兹号航母进入南海', 'Location Sentence': '此前，“尼米兹”号航母打击群与山东舰航母编队同在台岛以东海域活动。在4月7日和8日，美国信息公布平台DVID证实，4月7号和8号，美国海军“尼米兹”号航母在菲律宾海进行舰载机飞行训练。', 'Nationality Sentence': '【文/观察者网王世纯】根据美国国防部下属的信息发布网站DVID在4月16日报道，4月16号，美国海军“尼米兹”号（CVN-68）及其护航舰艇又一次进入南海，进行水面、空中以及水下作战训练，以及固定翼舰载机和舰载直升机的飞行训练。这是“尼米兹”号航母打击群自去年12月部署以来第3次进入南海。', 'Date Sentence': ''}, {'Ship Name': '军舰', 'Location': '东部海域', 'Nationality': '美', 'Date': '2016-07-10', 'File Name': 'File number 2', 'Ship Sentence': '美7艘军舰集结南海与日等境外势力', 'Location Sentence': '报道称，里根号6月在菲律宾东部海域的西太平洋上，与“约翰·斯坦尼斯”号实施了双航母联合训练。由里根号及随行的宙斯盾驱逐舰等组成的第五航母打击群指挥官约翰·亚历山大少将指出：“美国海军遵照国际法，在西太平洋实施航行、飞行及任务已超过一个世纪。今后也将继续。”以此强调本次活动的正当性。', 'Nationality Sentence': '美7艘军舰集结南海与日等境外势力', 'Date Sentence': ''}, {'Ship Name': '航母', 'Location': '', 'Nationality': '美国', 'Date': '2023-02-20', 'File Name': 'File number 3', 'Ship Sentence': '美国“尼米兹”航母打击群和“马金岛”两栖战备群在南海演习_中国航空新闻网', 'Location Sentence': '', 'Nationality Sentence': '美国“尼米兹”航母打击群和“马金岛”两栖战备群在南海演习_中国航空新闻网', 'Date Sentence': ''}, {'Ship Name': '尼米兹', 'Location': '已定海峡', 'Nationality': '美国', 'Date': '2023-04-22', 'File Name': 'File number 4', 'Ship Sentence': '美海军“尼米兹”号航母打击群今年第三次进入南海，“死期”已定', 'Location Sentence': '', 'Nationality Sentence': '最近一段时间以来，东亚地区的安全形势变得越来越严峻，在台海地区，美国从去年开始就一直在试图挑战中国底线，不仅与台湾当局往来密切，同时还多次为其提供武器，违反一个中国政策，而在朝鲜半岛，美韩之间也在不断加大对朝鲜的施压力度，导致朝鲜连续试射导弹，使战争爆发的可能性大幅增加。除了这两个地区以外，南海地区近期也并不太平，而美国也同样与之有关。', 'Date Sentence': ''}, {'Ship Name': '里根', 'Location': '的港口', 'Nationality': '美国', 'Date': '2022-07-29', 'File Name': 'File number 5', 'Ship Sentence': '“里根”号航母紧急再进南海想干啥？', 'Location Sentence': '南海战略态势感知的消息显示，7月26日晚，在结束对新加坡的港口访问后，美国海军“里根”号航母打击群再次进入南海，编队序列包括“里根”号航母、“安提坦”号导弹巡洋舰、“希金斯”号导弹驱逐舰和“蒂皮卡诺”号补给船。而南海战略态势感知7月28日更新的信息显示，截至28日9时许，“蒂皮卡诺”号补给船已经航行至越南以东洋面。有分析认为，这意味着“里根”号航母打击群正在一路向北高速航行。', 'Nationality Sentence': '美国“里根”号航母打击群又进南海！综合南海战略态势感知以及美国海军发布的信息，美国海军“里根”号航母打击群完成对新加坡的访问后，紧急进入南海。此外，一架美军RC-135V侦察机在27日异常进入南海上空。中国军事专家表示，从目前“里根”号航母开足马力北上的情况来看，它很可能是为佩洛西可能的窜访台湾做准备，而RC-135V则有可能为B-2轰炸机的巡航探路。美军如果将这些行动付诸实施，将极大增加地区不稳定因素。', 'Date Sentence': ''}, {'Ship Name': '航母', 'Location': '首次海上', 'Nationality': '美', 'Date': '2017-01-08', 'File Name': 'File number 6', 'Ship Sentence': '美航母来了', 'Location Sentence': '央视网消息：俄罗斯海军计划与菲方举行首次海上联合演练，美军“卡尔·文森”号核动力航空母舰正在驶向南海，辽宁舰也没闲着，正在南海巡航演练。中美俄三大国海上力量在2017年开年来到同一海域，地区局势将增加更多不确定性。', 'Nationality Sentence': '美航母来了', 'Date Sentence': ''}, {'Ship Name': '航母', 'Location': '文海上', 'Nationality': '美', 'Date': '2023-01-17', 'File Name': 'File number 7', 'Ship Sentence': '中美航母同处南海后，美“尼米兹”号为何高速驶离？', 'Location Sentence': '', 'Nationality Sentence': '中美航母同处南海后，美“尼米兹”号为何高速驶离？', 'Date Sentence': ''}, {'Ship Name': '舰船', 'Location': '东南海域', 'Nationality': '日', 'Date': '2021-10-31', 'File Name': 'File number 8', 'Ship Sentence': '美军舰船同时现身东海、南海，想搞什么事情？', 'Location Sentence': '前往东沙群岛东南海域', 'Nationality Sentence': '10月25日至26日', 'Date Sentence': ''}, {'Ship Name': '航母', 'Location': '文海上', 'Nationality': '美', 'Date': '2023-01-17', 'File Name': 'File number 9', 'Ship Sentence': '中美航母同处南海后，美“尼米兹”号为何高速驶离？', 'Location Sentence': '', 'Nationality Sentence': '中美航母同处南海后，美“尼米兹”号为何高速驶离？', 'Date Sentence': ''}, {'Ship Name': '罗斯福', 'Location': '马六甲海峡', 'Nationality': '美', 'Date': '2021-04-04', 'File Name': 'File number 10', 'Ship Sentence': '警惕！美“罗斯福”号航母进入南海', 'Location Sentence': '消息，据AIS信号显示，4月4日上午8时许，美海军“罗斯福”号航母打击群——“罗斯福”号航母、“拉塞尔”号驱逐舰、“邦克山”号巡洋舰——经由马六甲海峡进入南海活动。', 'Nationality Sentence': '警惕！美“罗斯福”号航母进入南海', 'Date Sentence': ''}, {'Ship Name': '航母', 'L ...
